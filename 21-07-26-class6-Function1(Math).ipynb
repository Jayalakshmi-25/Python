# %% [markdown]
# 1.Write a program to calculate the square root of a number using the `math` module.

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# 2.Find the cube root of a given number using mathematical operations.

# %%
math.cbrt(8)
# Out:
# 2.0

# %% [markdown]
# 3.Calculate the factorial of a number using math.factorial().

# %%
math.factorial(6)
# Out:
# 720

# %% [markdown]
# 4.Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().

# %%
math.gcd(25,60)
# Out:
# 5

# %% [markdown]
# 5.Find the LCM of two numbers using math.lcm()

# %%
math.lcm(12, 18)
# Out:
# 36

# %% [markdown]
# 6.Calculate the value of 5 raised to the power of 8 using math.pow().

# %%
math.pow(5, 8)
# Out:
# 390625.0

# %% [markdown]
# 7.Find the absolute value of a negative decimal number using math.fabs().

# %%
import math
num = -12.34
result = math.fabs(num)
print("Original number: ", num)
print("Absolute number: ", result)
# Out:
# Original number:  -12.34
# Absolute number:  12.34

# %% [markdown]
# 8.Round a floating-point number up using math.ceil().

# %%
number = 20.5
result = math.ceil(number)
print("original number: ", number)
print("Round up number: ", result)
# Out:
# original number:  20.5
# Round up number:  21

# %% [markdown]
# 9.Round a floating-point number down using math.floor().

# %%
number = 78.89
result = math.floor(number)
print("original number: ", number)
print("Round down number: ", result)
# Out:
# original number:  78.89
# Round down number:  78

# %% [markdown]
# 10.Round a floating-point number to the nearest integer using round().

# %%
number = 85.6
result = round(number)
print("original number: ", number)
print("Round  number: ", result)
# Out:
# original number:  85.6
# Round  number:  86

# %% [markdown]
# 11.Find the remainder of two numbers using math.fmod().

# %%
a, b = 25, 6
result = math.fmod(a, b)
print("Reminder of two numbers: ", result)
# Out:
# Reminder of two numbers:  1.0

# %% [markdown]
# 12.Find the quotient and remainder using divmod().

# %%
a, b= 18, 9
quotient, remainder = divmod(a, b)
print("Quotient:", quotient)
print("Remainder:", remainder)
# Out:
# Quotient: 2
# Remainder: 0

# %% [markdown]
# 13.Calculate the sine, cosine, and tangent of 45 degrees.

# %%
x = 45
print(math.sin(x))
print(math.cos(x))
print(math.tan(x))
# Out:
# 0.8509035245341184
# 0.5253219888177297
# 1.6197751905438615

# %% [markdown]
# 14.Convert an angle from degrees to radians.

# %%
degrees = 90
radians = math.radians(degrees)
print("Degrees:", degrees)
print("Radians:", radians)
# Out:
# Degrees: 90
# Radians: 1.5707963267948966

# %% [markdown]
# 15.Convert an angle from radians to degrees.

# %%
radians = math.pi
degrees = math.degrees(radians)
print("Radians:", radians)
print("Degrees:", degrees)
# Out:
# Radians: 3.141592653589793
# Degrees: 180.0

# %% [markdown]
# 16.Find the logarithm (base 10) of a number using math.log10().

# %%
base = 10
print(math.log10(base))
# Out:
# 1.0

# %% [markdown]
# 17.Find the natural logarithm of a number using math.log().

# %%
number =  10
result = math.log(number)
print("Original: ",number)
print("Natural number: ",result)
# Out:
# Original:  10
# Natural number:  2.302585092994046

# %% [markdown]
# 18.Calculate e raised to the power of x using math.exp().

# %%
x = 2
result = math.exp(x)
print("Power of x is: ",result)
# Out:
# Power of x is:  7.38905609893065

# %% [markdown]
# 19.Find the value of π (pi) and Euler's number (e) from the math module.

# %%
import math
print("Value of pi:",math.pi)
print("Value of e: ",math.e)
# Out:
# Value of pi: 3.141592653589793
# Value of e:  2.718281828459045

# %% [markdown]
# 20.Find the distance between two points using math.dist().

# %%
a, b = ((1,4),(6,8))
result = math.dist(a, b)
print("Distance between two points: ",result)
# Out:
# Distance between two points:  6.4031242374328485

# %% [markdown]
# 21.Calculate the hypotenuse of a right triangle using math.hypot().

# %%
a, b = 8, 9
result=math.hypot(a, b)
print("Hypotenuse of a right triangle: ",result)
# Out:
# Hypotenuse of a right triangle:  12.041594578792296

# %% [markdown]
# 22.Find the combination (nCr) using math.comb().

# %%
a, b = 2, 1
result = math.comb(a, b)
print("Combinations: ", result)
# Out:
# Combinations:  2

# %% [markdown]
# 23.Find the permutation (nPr) using math.perm().

# %%
a, b = 5, 2
result = math.perm(a, b)
print("Permutations: ", result)
# Out:
# Permutations:  20

# %% [markdown]
# 24.Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().

# %%
number = 35
print(math.isfinite(number))
print(math.isinf(number))
print(math.isnan(number))
# Out:
# True
# False
# False

# %% [markdown]
# 25.Find the product of all numbers in a list using math.prod().

# %%
list = [2,4,6,8,10]
result=math.prod(list)
print("Product of all numbers: ",result)
# Out:
# Product of all numbers:  3840

# %% [markdown]
# 26.Find the sum of square roots of all numbers in a list.

# %%
numbers = [4, 9, 16, 25]
result = sum(math.sqrt(num) for num in numbers)
print("Sum of square roots: ",result)
# Out:
# Sum of square roots:  14.0

# %% [markdown]
# 27.Find the largest integer less than or equal to the square root of a given number.

# %%
number = 20
result = math.floor(math.sqrt(number))
print("Number: ", number)
print("Largest integer <= Square root: ",result)
# Out:
# Number:  20
# Largest integer <= Square root:  4

# %% [markdown]
# 28.Calculate compound interest using math.pow().

# %%
principal = 10000
rate = 5
time = 2
amount = principal * math.pow((1 + rate / 100), time)
compound_interest = amount - principal
print("Amount:", amount)
print("Compound Interest:", compound_interest)
# Out:
# Amount: 11025.0
# Compound Interest: 1025.0

# %% [markdown]
# 29.Find the area and circumference of a circle using math.pi

# %%
r = 5
area = math.pi*r**2
circumference = 2*math.pi**2
print("Radius:", r)
print("Area:", area)
print("Circumference:", circumference)
# Out:
# Radius: 5
# Area: 78.53981633974483
# Circumference: 19.739208802178716

# %% [markdown]
# 30.Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

# %%
import math
print("1. Square Root")
print("2. Factorial")
print("3. Log")
print("4. Power")
print("5. Trigonometric Functions")
print("6. GCD")
print("7. LCM")
choice = int(input("Enter choice: "))
if choice == 1:
    number = float(input("Enter number: "))
    print("Square root:", math.sqrt(number))
elif choice == 2:
    number = int(input("Enter number: "))
    print("Factorial:", math)
elif choice == 3:
    number = float(input("Enter number: "))
    print("Log:", math.log(number))
    print("Log10:", math.log10(number))
    print("Log2:", math.log2(number))
    print("Log1p:", math.log1p(number))
elif choice == 4:
    base = float(input("Enter base: "))
    exponent = float(input("Enter exponent: "))
    print("Power:", math.pow(base, exponent))
elif choice == 5:
    print("1. Sine")
    print("2. Cosine")
    print("3. Tangent")
    print("4. Cotangent")
    print("5. Secant")
    print("6. Cosecant")
    choice = int(input("Enter choice: "))
    angle = float(input("Enter angle: "))
    if choice == 1:
        print("Sine:", math.sin(math.radians(angle)))
    elif choice == 2:
        print("Cosine:", math.cos(math.radians(angle)))
    elif choice == 3:
        print("Tangent:", math.tan(math.radians(angle)))
    elif choice == 4:
        print("Cotangent:", 1 / math.tan(math.radians(angle)))
    elif choice == 5:
        print("Secant:", 1 / math.cos(math.radians(angle)))
    elif choice == 6:
        print("Cosecant:", 1 / math.sin(math.radians(angle)))
    else:
        print("Invalid choice")
elif choice == 6:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("GCD:", math.gcd(a, b))
elif choice == 7:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("LCM:", math.lcm(a, b))
else:
     print("Invalid choice")
# Out:
# 1. Square Root
# 2. Factorial
# 3. Log
# 4. Power
# 5. Trigonometric Functions
# 6. GCD
# 7. LCM
# Enter choice: 3
# Enter number: 4
# Log: 1.3862943611198906
# Log10: 0.6020599913279624
# Log2: 2.0
# Log1p: 1.6094379124341003
