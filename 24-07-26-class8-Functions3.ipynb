# %% [markdown]
# Section 1: Lambda Expressions — 20 Questions

# %% [markdown]
# Question 1:Write a lambda expression to calculate the square of number.

# %%
number = 8
square = lambda x: x**2
print(square(number))
# Out:
# 64

# %% [markdown]
# Question 2:Write a lambda expression to calculate the cube of number.

# %%
number = 5
cube = lambda x: x**3
print(cube(number))
# Out:
# 125

# %% [markdown]
# Question 3:Write a lambda expression to add a and b.

# %%
a = 25
b = 17
add = lambda a, b: a+b
print(add(a, b))
# Out:
# 42

# %% [markdown]
# Question 4:Write a lambda expression to subtract b from a.

# %%
a = 50
b = 18
subtract = lambda a, b: a-b
print(subtract(a, b))
# Out:
# 32

# %% [markdown]
# Question 5:Write a lambda expression to multiply a and b.

# %%
a = 12
b = 9
multiply = lambda a, b: a*b
print(multiply(a, b))
# Out:
# 108

# %% [markdown]
# Question 6:Write a lambda expression to divide a by b.

# %%
a = 100
b = 4
divide = lambda a, b: a/b
print(divide(a, b))
# Out:
# 25.0

# %% [markdown]
# Question 7:Write a lambda expression to return the larger number.

# %%
a = 72
b = 91
larger = lambda a, b: max(a, b)
print(larger(a, b))
# Out:
# 91

# %% [markdown]
# Question 8:Write a lambda expression to return the smaller number.

# %%
a = 46
b = 28
smaller = lambda a, b: min(a, b)
print(smaller(a, b))
# Out:
# 28

# %% [markdown]
# Question 9:Write a lambda expression that returns True when the number is even and False otherwise.

# %%
number = 34
even = lambda number: number%2==0
print(even(number))
# Out:
# True

# %% [markdown]
# Question 10:Write a lambda expression that returns True when the number is odd and False otherwise.

# %%
number = 27
odd = lambda number: number%2!=0
print(odd(number))
# Out:
# True

# %% [markdown]
# Question 11:Write a lambda expression to calculate the area of a rectangle.

# %%
length = 12
width = 8
rectangle = lambda length, width: length*width
print(rectangle(length, width))
# Out:
# 96

# %% [markdown]
# Question 12:Write a lambda expression to calculate the area of a circle using 3.14.

# %%
radius = 7
circle = lambda radius: 3.14*radius**2
print(circle(radius))
# Out:
# 153.86

# %% [markdown]
# Question 13:Write a lambda expression to calculate the perimeter of a rectangle.

# %%
length = 15
width = 10
rectangle = lambda length, width: 2*(length+width)
print(rectangle(length, width))
# Out:
# 50

# %% [markdown]
# Question 14:Write a lambda expression to convert Celsius into Fahrenheit.

# %%
celsius = 35
fahrenheit = lambda celsius: (celsius*9/5)+32
print(fahrenheit(celsius))
# Out:
# 95.0

# %% [markdown]
# Question 15:Write a lambda expression to convert Fahrenheit into Celsius.

# %%
fahrenheit = 104
celsius = lambda fahrenheit: (fahrenheit-32)*5/9
print(celsius(fahrenheit))
# Out:
# 40.0

# %% [markdown]
# Question 16:Write a lambda expression to return the length of the string.

# %%
word = "Python"
length = lambda word: len(word)
print(length(word))
# Out:
# 6

# %% [markdown]
# Question 17:Write a lambda expression to return the first character of the string.

# %%
word = "Programming"
first = lambda word: word[0]
print(first(word))
# Out:
# P

# %% [markdown]
# Question 18:Write a lambda expression to return the last character of the string.

# %%
word = "Databricks"
last = lambda word: word[-1]
print(last(word))
# Out:
# s

# %% [markdown]
# Question 19:Write a lambda expression to return the absolute value of the number without using abs().

# %%
number = -45
absolute = lambda number: number*(-1) if number<0 else number
print(absolute(number))
# Out:
# 45

# %% [markdown]
# Question 20:Write a lambda expression that returns:
#
# "Distinction" when marks are 75 or above
# "Pass" when marks are 40 to 74
# "Fail" when marks are below 40

# %%
marks = 72
result = lambda marks: "Distinction" if marks>=75 else "Pass" if marks>=40 else "Fail"
print(result(marks))
# Out:
# Pass

# %% [markdown]
# **Section 2: map() — 20 Questions**

# %% [markdown]
# Question 1:Using map() and a lambda expression, calculate the square of every number.

# %%
numbers = [1, 2, 3, 4, 5, 6]
square = list(map(lambda x: x**2, numbers))
print(square)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# Question 2:Using map() and a lambda expression, calculate the cube of every number.

# %%
numbers = [2, 3, 4, 5, 6]
cube = list(map(lambda x: x**3, numbers))
print(cube)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# Question 3:Using map(), add 5 to every number

# %%
numbers = [10, 20, 30, 40, 50]
add = list(map(lambda x: x+5, numbers))
print(add)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# Question 4:Using map(), subtract 10 from every number.

# %%
numbers = [15, 25, 35, 45, 55]
subtract = list(map(lambda x: x-10, numbers))
print(subtract)
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# Question 5:Using map(), multiply every number by 100.

# %%
numbers = [1, 5, 10, 15, 20]
multiply = list(map(lambda x: x*100, numbers))
print(multiply)
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# Question 6:Using map(), convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
uppercase = list(map(lambda x: x.upper(), names))
print(uppercase)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# Question 7:Using map(), convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
lowercase = list(map(lambda x: x.lower(), names))
print(lowercase)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# Question 8:Using map(), convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
title = list(map(lambda x: x.title(), names))
print(title)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# Question 9:Using map(), calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
length = list(map(lambda x: len(x), words))
print(length)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# Question 10:Using map(), extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
character = list(map(lambda x: x[0], words))
print(character)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# Question 11:Using map(), extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
character = list(map(lambda x: x[-1], words))
print(character)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# Question 12:Using map(), convert every Celsius temperature into Fahrenheit.$0

# %%
temperatures = [0, 10, 20, 30, 40]
celsius_to_fahrenheit = lambda celsius: (celsius*9/5)+32
fahrenheit = list(map(celsius_to_fahrenheit, temperatures))
print(fahrenheit)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# Question 13:Using map(), calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]
GST = lambda price: price*0.18
gst = list(map(GST, prices))
print(gst)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# Question 14:Using map(), calculate the final price after adding 18% GST

# %%
prices = [100, 250, 500, 1000, 2500]
final_price = lambda price: price+price*0.18
final_price_list = list(map(final_price, prices))
print(final_price_list)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# Question 15:sing map(), round every number to two decimal places.

# %%
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
round_numbers = list(map(lambda x: round(x, 2), decimal_numbers))
print(round_numbers)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# Question 16:Using map(), convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
absolute = list(map(lambda x: abs(x), values))
print(absolute)
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# Question 17:Using map(), convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
string = list(map(lambda x: str(x), numbers))
print(string)
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# Question 18:Using map(), remove leading and trailing spaces from every name.

# %%
names = ["  Ravi  ", " Anil", "Meena ", "  Kiran "]
spaces = list(map(lambda x : x.strip(), names))
print(spaces)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# Question 19:Using map(), extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
names = list(map(lambda x: x["name"], employees))
print(names)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# Question 20:Using map(), create a new list of dictionaries containing:
#
# Employee name
# Original salary
# Salary after a 10% increment
# Do not modify the original list.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
new_list = list(map(lambda x: {"name": x["name"], "original_salary": x["salary"], "salary_after_increment": x["salary"]*1.1}, employees))
print(new_list)
# Out:
# [{'name': 'Rahul', 'original_salary': 45000, 'salary_after_increment': 49500.00000000001}, {'name': 'Anil', 'original_salary': 65000, 'salary_after_increment': 71500.0}, {'name': 'Sneha', 'original_salary': 72000, 'salary_after_increment': 79200.0}, {'name': 'Kiran', 'original_salary': 82000, 'salary_after_increment': 90200.00000000001}]

# %% [markdown]
# **Section 3: filter() — 20 Questions**

# %% [markdown]
# Question 1:Using filter(), extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even = list(filter(lambda x: x%2==0, numbers))
print(even)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# Question 2:Using filter(), extract all odd numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd = list(filter(lambda x: x%2!=0, numbers))
print(odd)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# Question 3:Using filter(), extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
greater_than_50 = list(filter(lambda x: x>50, numbers))
print(greater_than_50)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# Question 4:Using filter(), extract all numbers less than 100.

# %%
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
less_than_100 = list(filter(lambda x: x<100, numbers))
print(less_than_100)
# Out:
# [45, 89, 56, 91, 34]

# %% [markdown]
# Question 5:Using filter(), extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
positive = list(filter(lambda x: x>0, numbers))
print(positive)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# Question 6:Using filter(), extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
negative = list(filter(lambda x: x<0, numbers))
print(negative)
# Out:
# [-15, -8, -25]

# %% [markdown]
# Question 7:Using filter(), remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
remove_zero = list(filter(lambda x: x!=0, numbers))
print(remove_zero)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# Question 8:Using filter(), extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
more_than_five = list(filter(lambda x: len(x)>5, words))
print(more_than_five)
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# Question 9:Using filter(), extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
names_starting_with_A = list(filter(lambda x: x[0]=="A", names))
print(names_starting_with_A)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# Question 10:Using filter(), extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
names_ending_with_n = list(filter(lambda x: x[-1]=="n", names))
print(names_ending_with_n)
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# Question 11:Using filter(), extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
multiples_of_5 = list(filter(lambda x: x%5==0, numbers))
print(multiples_of_5)
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# Question 12:Using filter(), extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
divisible_by_3_and_5 = list(filter(lambda x: x%3==0 and x%5==0, numbers))
print(divisible_by_3_and_5)
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# Question 13:Using filter(), extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindrome = list(filter(lambda x: x==x[::-1], words))
print(palindrome)
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# Question 14:Using filter(), extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
]
email_addresses_ending_with_dotcom= list(filter(lambda x: x.endswith(".com"), emails))
print(email_addresses_ending_with_dotcom)
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# Question 15:Using filter(), extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]
csv = list(filter(lambda x: x.endswith(".csv"), files))
print(csv)
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# Question 16:Using filter(), extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
salary_greater_than_60000 = list(filter(lambda x: x["salary"]>60000, employees))
print(salary_greater_than_60000)
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# Question 17:Using filter(), extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
marks_greater_than_80 = list(filter(lambda x: x["marks"]>80, students))
print(marks_greater_than_80)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# Question 18:Using filter(), extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
products_in_stock = list(filter(lambda x: x["stock"]>0, products))
print(products_in_stock)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# Question 19:Using filter(), extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
eligible_to_vote = list(filter(lambda x: x["age"]>=18, people))
print(eligible_to_vote)
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}, {'name': 'Meena', 'age': 18}]

# %% [markdown]
# Question 20:Using filter(), extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
it_department_active = list(filter(lambda x: x["department"]=="IT" and x["active"]==True, employees))
print(it_department_active)
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True}, {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# **Section 4: reduce() — 20 Questions**

# %% [markdown]
# Question 1:Using reduce(), calculate the sum of all numbers.

# %%
from functools import reduce
numbers=[10,20,30,40,50]
sum = reduce(lambda x,y:x+y,numbers)
print(sum)
# Out:
# 150

# %% [markdown]
# Question 2:Using reduce(), calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]
product = reduce(lambda x, y: x*y, numbers)
print(product)
# Out:
# 120

# %% [markdown]
# Question 3:Using reduce(), find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
maximum = reduce(lambda x, y: x if x>y else y, numbers)
print(maximum)
# Out:
# 91

# %% [markdown]
# Question 4:Using reduce(), find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
minimum = reduce(lambda x, y: x if x<y else y, numbers)
print(minimum)
# Out:
# 12

# %% [markdown]
# Question 5:Using reduce(), combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]
sentence = reduce(lambda x, y: x+y, words)
print(sentence)
# Out:
# Python is powerful

# %% [markdown]
# Question 6:Using reduce(), calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]
total_characters = reduce(lambda x, y: x + len(y), words, 0)
print(total_characters)
# Out:
# 18

# %% [markdown]
# Question 7:Using reduce(), calculate the factorial of number.

# %%
number = 6
numbers = list(range(1, number + 1))
factorial = reduce(lambda x, y: x*y, numbers)
print(factorial)
# Out:
# 720

# %% [markdown]
# Question 8:Using reduce(), calculate the sum of only the even numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
sum_of_even = reduce(lambda x, y: x+y if y%2==0 else x, numbers, 0)
print(sum_of_even)
# Out:
# 280

# %% [markdown]
# Question 9:Using reduce(), calculate the sum of only the odd numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
sum_of_odd = reduce(lambda x, y: x+y if y%2!=0 else x, numbers, 0)
print(sum_of_odd)
# Out:
# 315

# %% [markdown]
# Question 10:Using reduce(), find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
longgest_word = reduce(lambda x, y: x if len(x)>len(y) else y, words)
print(longgest_word)
# Out:
# Kubernetes

# %% [markdown]
# Question 11:Using reduce(), find the shortest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
shortest_word = reduce(lambda x, y: x if len(x)<len(y) else y, words)
print(shortest_word)
# Out:
# AI

# %% [markdown]
# Question 12:Using reduce(), calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]
total_salary = reduce(lambda x, y: x+y, salaries)
print(total_salary)
# Out:
# 319000

# %% [markdown]
# Question 13:Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
total_payroll = reduce(lambda x, y: x+y["salary"], employees, 0)
print(total_payroll)
# Out:
# 319000

# %% [markdown]
# Question 14:Using reduce(), find the employee with the highest salary.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
employee_with_highest_salary = reduce(lambda x, y: x if x["salary"]>y["salary"] else y, employees)
print(employee_with_highest_salary)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# Question 15:Using reduce(), find the student with the highest marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
student_with_highest_marks = reduce(lambda x, y: x if x["marks"]>y["marks"] else y, students)
print(student_with_highest_marks)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# Question 16:Using reduce(), calculate the total stock quantity.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
total_stock = reduce(lambda x, y: x+y["stock"], products, 0)
print(total_stock)
# Out:
# 53

# %% [markdown]
# Question 17:Using reduce(), calculate the total inventory value using price × stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
total_inventory_value = reduce(lambda x, y: x+y["price"]*y["stock"], products, 0)
print(total_inventory_value)
# Out:
# 456500

# %% [markdown]
# Question 18:Using reduce(), calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]
total_sales = reduce(lambda x, y: x+y, sales)
print(total_sales)
# Out:
# 182000

# %% [markdown]
# Question 19:Using reduce(), merge all dictionaries into one dictionary.

# %%
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
merged_dictionary = reduce(lambda x, y: {**x, **y}, dictionaries)
print(merged_dictionary)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# Question 20:numbers =Using reduce(), calculate the sum of unique numbers only. Do not directly use sum(set(numbers)).

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
unique_sum = reduce(lambda x, y: x+y if y not in x else x, numbers, set(numbers))
print(unique_sum)
# Out:
# {67, 100, 12, 45, 23, 89}

# %% [markdown]
# **Section 5: Combined Lambda, map(), filter(), and reduce() — 20 Questions**

# %% [markdown]
# Question 1:Using filter() and map():
#
# 1.Extract all even numbers.
# 2.Calculate the square of every even number.
# 3.Return the squared values as a list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even_numbers = list(filter(lambda x: x%2==0, numbers))
squared_numbers = list(map(lambda x: x**2, even_numbers))
print("even_numbers:", even_numbers)
print("squared_numbers:", squared_numbers)
# Out:
# even_numbers: [12, 56, 34, 78, 100]
# squared_numbers: [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# Question 2:Using filter() and reduce():
#
# 1.Extract all odd numbers.
# 2.Calculate their total sum

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd_numbers = list(filter(lambda x: x%2!=0, numbers))
sum_of_odd_numbers = reduce(lambda x, y: x+y, odd_numbers)
print(odd_numbers)
print(sum_of_odd_numbers)
# Out:
# [45, 67, 89, 23, 91]
# 315

# %% [markdown]
# Question 3:Using filter() and map():
#
# 1.Extract numbers greater than 50.
# 2.Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
greater_than_50 = list(filter(lambda x: x>50, numbers))
multiplied_numbers = list(map(lambda x: x*2, greater_than_50))
print(greater_than_50)
print(multiplied_numbers)
# Out:
# [55, 70, 85, 100]
# [110, 140, 170, 200]

# %% [markdown]
# Question 4:Using filter(), map(), and reduce():
#
# 1.Extract positive numbers.
# 2.Calculate the square of every positive number.
# 3.Calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]
positive_numbers = list(filter(lambda x: x>0, numbers))
squared_numbers = list(map(lambda x: x**2, positive_numbers))
total_sum = reduce(lambda x, y: x+y, squared_numbers)
print(positive_numbers)
print(squared_numbers)
print(total_sum)
# Out:
# [20, 40, 50, 60]
# [400, 1600, 2500, 3600]
# 8100

# %% [markdown]
# Question 5:Using filter() and map():
#
# 1.Extract words containing more than five characters.
# 2.Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
more_than_five_characters = list(filter(lambda x: len(x)>5, words))
uppercase_words = list(map(lambda x: x.upper(), more_than_five_characters))
print(more_than_five_characters)
print(uppercase_words)
# Out:
# ['python', 'developer', 'analytics']
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# Question 6:Using filter() and map():
#
# 1.Extract names beginning with "A".
# 2.Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
names_starting_with_A = list(filter(lambda x: x[0]=="A", names))
lowercase_names = list(map(lambda x: x.lower(), names_starting_with_A))
print(names_starting_with_A)
print(lowercase_names)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# Question 7:Using filter() and reduce():
#
# 1.Extract numbers divisible by both 3 and 5.
# 2.Calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
divisible_by_3_and_5 = list(filter(lambda x: x%3==0 and x%5==0, numbers))
total_sum = reduce(lambda x, y: x+y, divisible_by_3_and_5)
print(divisible_by_3_and_5)
print(total_sum)
# Out:
# [15, 30, 45, 60, 75]
# 225

# %% [markdown]
# Question 8:Using filter() and reduce():
#
# 1.Extract palindrome words.
# 2.Join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindrom = list(filter(lambda x: x==x[::-1], words))
joined_string = reduce(lambda x, y: x+" | "+y, palindrom)
print(palindrom)
print(joined_string)
# Out:
# ['madam', 'level', 'radar', 'civic']
# madam | level | radar | civic

# %% [markdown]
# Question 9:Using filter(), map(), and reduce():
#
# 1.Extract temperatures greater than 30°C.
# 2.Convert the selected values into Fahrenheit.
# 3.Calculate the average Fahrenheit temperature.

# %%
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
greater_than_30 = list(filter(lambda x: x>30, temperatures))
fahrenheit = list(map(lambda x: (x*9/5)+32, greater_than_30))
average_fahrenheit = reduce(lambda x, y: x+y, fahrenheit)/len(fahrenheit)
print(greater_than_30)
print(fahrenheit)
print(average_fahrenheit)
# Out:
# [35, 40, 33, 42]
# [95.0, 104.0, 91.4, 107.6]
# 99.5

# %% [markdown]
# Question 10:Using filter(), map(), and reduce():
#
# 1.Extract prices greater than 1000.
# 2.Apply a 10% discount to every selected price.
# 3.Calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
greater_than_1000 = list(filter(lambda x: x>1000, prices))
discounted_prices = list(map(lambda x: x*0.9, greater_than_1000))
discounted_amount = reduce(lambda x, y: x+y, discounted_prices)
print(greater_than_1000)
print(discounted_prices)
print(discounted_amount)
# Out:
# [1200, 2500, 5000, 1500, 7500]
# [1080.0, 2250.0, 4500.0, 1350.0, 6750.0]
# 15930.0

# %% [markdown]
# Question 11:Using filter() and map():
#
# 1.Extract employees earning more than 60000.
# 2.Increase their salary by 10%.
# 3.Return their names and updated salaries.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
greater_than_60000 = list(filter(lambda x: x["salary"]>60000, employees))
increased_salary = list(map(lambda x: {"id": x["id"], "name": x["name"], "salary": x["salary"]*1.1}, greater_than_60000))
names_and_updated_salaries = list(map(lambda x: {"name": x["name"], "salary": x["salary"]}, increased_salary))
print(greater_than_60000)
print(increased_salary)
print(names_and_updated_salaries)
# Out:
# [{'id': 102, 'name': 'Anil', 'salary': 65000}, {'id': 103, 'name': 'Sneha', 'salary': 72000}, {'id': 104, 'name': 'Kiran', 'salary': 82000}]
# [{'id': 102, 'name': 'Anil', 'salary': 71500.0}, {'id': 103, 'name': 'Sneha', 'salary': 79200.0}, {'id': 104, 'name': 'Kiran', 'salary': 90200.00000000001}]
# [{'name': 'Anil', 'salary': 71500.0}, {'name': 'Sneha', 'salary': 79200.0}, {'name': 'Kiran', 'salary': 90200.00000000001}]

# %% [markdown]
# Question 12:Using filter() and reduce():
#
# 1.Extract employees from the IT department.
# 2.Calculate the total salary of IT employees.

# %%
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
it_employees = list(filter(lambda x: x["department"]=="IT", employees))
total_salary = reduce(lambda x, y: x+y["salary"], it_employees, 0)
print(it_employees)
print(total_salary)
# Out:
# [{'id': 101, 'name': 'Rahul', 'department': 'IT', 'salary': 45000}, {'id': 103, 'name': 'Sneha', 'department': 'IT', 'salary': 72000}, {'id': 104, 'name': 'Kiran', 'department': 'IT', 'salary': 82000}]
# 199000

# %% [markdown]
# Question 13:Using filter(), map(), and reduce():
#
# 1.Extract active employees.
# 2.Increase every active employee's salary by 15%.
# 3.Calculate the total updated payroll.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
active_employees = list(filter(lambda x: x["active"]==True, employees))
increased_salary = list(map(lambda x: {"id": x["id"], "name": x["name"], "salary": x["salary"]*1.1}, active_employees))
total_updated_payroll = reduce(lambda x, y: x+y["salary"], increased_salary, 0)
print(active_employees)
print(increased_salary)
print(total_updated_payroll)
# Out:
# [{'id': 101, 'name': 'Rahul', 'salary': 45000, 'active': True}, {'id': 102, 'name': 'Anil', 'salary': 65000, 'active': True}, {'id': 104, 'name': 'Kiran', 'salary': 82000, 'active': True}, {'id': 105, 'name': 'Meena', 'salary': 55000, 'active': True}]
# [{'id': 101, 'name': 'Rahul', 'salary': 49500.00000000001}, {'id': 102, 'name': 'Anil', 'salary': 71500.0}, {'id': 104, 'name': 'Kiran', 'salary': 90200.00000000001}, {'id': 105, 'name': 'Meena', 'salary': 60500.00000000001}]
# 271700.0

# %% [markdown]
# Question 14:Using filter() and reduce():
#
# 1.Extract students who passed.
# 2.Find the topper among the passed students.

# %%
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
passed_students = list(filter(lambda x: x["passed"]==True, students))
topper = reduce(lambda x, y: x if x["marks"]>y["marks"] else y, passed_students)
print(passed_students)
print(topper)
# Out:
# [{'name': 'Ravi', 'marks': 92, 'passed': True}, {'name': 'Kiran', 'marks': 68, 'passed': True}, {'name': 'Meena', 'marks': 85, 'passed': True}, {'name': 'Ajay', 'marks': 48, 'passed': True}, {'name': 'Rahul', 'marks': 95, 'passed': True}]
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# Question 15:Using filter(), map(), and reduce():
#
# 1.Extract students scoring more than 70.
# 2.Extract only their marks.
# 3.Calculate the average marks.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
more_than_70 = list(filter(lambda x: x["marks"]>70, students))
marks = list(map(lambda x: x["marks"], more_than_70))
average_marks = reduce(lambda x, y: x+y, marks)/len(marks)
print(more_than_70)
print(marks)
print(average_marks)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}, {'name': 'Sneha', 'marks': 79}, {'name': 'Rahul', 'marks': 95}]
# [92, 85, 79, 95]
# 87.75

# %% [markdown]
# Question 16:Using filter(), map(), and reduce():
#
# 1.Extract products currently in stock.
# 2.Calculate each product's inventory value using price × stock.
# 3.Calculate the total inventory value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
in_stock = list(filter(lambda x: x["stock"]>0, products))
inventory_value = list(map(lambda x: x["price"]*x["stock"], in_stock))
total_inventory_value = reduce(lambda x, y: x+y, inventory_value)
print(in_stock)
print(inventory_value)
print(total_inventory_value)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}, {'name': 'SSD', 'price': 6500, 'stock': 12}]
# [275000, 15000, 144000, 78000]
# 512000

# %% [markdown]
# Question 17:Using filter(), map(), and reduce():
#
# 1.Extract products belonging to the 2.Electronics category.
# Apply a 20% discount.
# 3.Calculate the total discounted value.

# %%
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
electronics = list(filter(lambda x: x["category"]=="Electronics", products))
discounted_price = list(map(lambda x: {"name": x["name"], "price": x["price"]*0.8}, electronics))
total_discounted_value = reduce(lambda x, y: x+y["price"], discounted_price, 0)
print(electronics)
print(discounted_price)
print(total_discounted_value)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'category': 'Electronics'}, {'name': 'Monitor', 'price': 18000, 'category': 'Electronics'}, {'name': 'SSD', 'price': 6500, 'category': 'Electronics'}]
# [{'name': 'Laptop', 'price': 44000.0}, {'name': 'Monitor', 'price': 14400.0}, {'name': 'SSD', 'price': 5200.0}]
# 63600.0

# %% [markdown]
# Question 18:Using filter() and reduce():
#
# 1.Extract delivered orders.
# 2.Calculate the total delivered revenue.

# %%
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
delivered_orders = list(filter(lambda x: x["status"]=="Delivered", orders))
total_delivered_revenue = reduce(lambda x, y: x+y["amount"], delivered_orders, 0)
print(delivered_orders)
print(total_delivered_revenue)
# Out:
# [{'order_id': 1001, 'amount': 1200, 'status': 'Delivered'}, {'order_id': 1003, 'amount': 8500, 'status': 'Delivered'}, {'order_id': 1005, 'amount': 7600, 'status': 'Delivered'}]
# 17300

# %% [markdown]
# Question 19:Using filter(), map(), and reduce():
#
# 1.Extract transactions whose amount is greater than 5000.
# 2.Add 18% GST to every selected transaction.
# 3.Calculate the grand total after GST.

# %%
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
greater_than_5000 = list(filter(lambda x: x["amount"]>5000, transactions))
gst = list(map(lambda x: {"id": x["id"], "amount": x["amount"]*1.18}, greater_than_5000))
grand_total = reduce(lambda x, y: x+y["amount"], gst, 0)
print(greater_than_5000)
print(gst)
print(grand_total)
# Out:
# [{'id': 2, 'amount': 5200}, {'id': 3, 'amount': 18000}, {'id': 5, 'amount': 9600}, {'id': 6, 'amount': 7200}]
# [{'id': 2, 'amount': 6136.0}, {'id': 3, 'amount': 21240.0}, {'id': 5, 'amount': 11328.0}, {'id': 6, 'amount': 8496.0}]
# 47200.0

# %% [markdown]
# Question 20:Using filter(), map(), and reduce():
#
# 1.Extract active salespeople from the South region.
# 2.Calculate a 5% incentive for each selected salesperson.
# 3.Create a list containing salesperson name, sales amount, and incentive.
# 4.Calculate the total incentive payable.

# %%
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
south_region = list(filter(lambda x: x["region"]=="South" and x["active"]==True, sales_records))
incentive = list(map(lambda x: {"salesperson": x["salesperson"], "sales": x["sales"], "incentive": x["sales"]*0.05}, south_region))
salesperson_sales_incentive = list(map(lambda x: {"salesperson": x["salesperson"], "sales": x["sales"], "incentive": x["incentive"]}, incentive))
total_incentive = reduce(lambda x, y: x+y["incentive"], salesperson_sales_incentive, 0)
print(south_region)
print(incentive)
print(salesperson_sales_incentive)
print(total_incentive)
# Out:
# [{'salesperson': 'Rahul', 'region': 'South', 'sales': 45000, 'active': True}, {'salesperson': 'Kiran', 'region': 'South', 'sales': 82000, 'active': True}, {'salesperson': 'Arjun', 'region': 'South', 'sales': 98000, 'active': True}]
# [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# 11250.0
