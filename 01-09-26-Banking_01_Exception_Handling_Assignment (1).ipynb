# %% [markdown]
# # Banking Assignment — Exception Handling (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice try/except, custom exceptions, chaining, cleanup, resilient batch processing. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Parse a deposit amount for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class DepositError(Exception):
    pass

def deposit(account, balance, amount):
    try:
        amount = float(amount)
    except (TypeError, ValueError) as e:
        raise DepositError("Invalid deposit amount") from e
    if amount <= 0:
        raise DepositError("Amount must be greater than 0")
    return balance + amount
account = "ACC-1001"
balance = 5000
try:
    balance = deposit(account, balance, "1500")
    print(account, "New Balance:", balance)
except DepositError as e:
    print("Error:", e)
# Out:
# ACC-1001 New Balance: 6500.0

# %% [markdown]
# ### Q2. Handle a missing account key for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1002"
balance = 5000
try:
    print(account, "New Balance:", balance)
    raise KeyError("Invalid account number")
except KeyError as e:
    print("Error:", e)
# Out:
# ACC-1002 New Balance: 5000
# Error: 'Invalid account number'

# %% [markdown]
# ### Q3. Prevent division by zero in average balance for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1003"
balance = 5000
try:
    print(account, "New Balance:", balance)
    raise ZeroDivisionError("Division by zero")
except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# ACC-1003 New Balance: 5000
# Error: Division by zero

# %% [markdown]
# ### Q4. Open a transaction file safely for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1004"
try:
    print(account, "New Balance:", balance)
    raise FileNotFoundError("File not found")
except FileNotFoundError as e:
    print("Error:", e)
# Out:
# ACC-1004 New Balance: 5000
# Error: File not found

# %% [markdown]
# ### Q5. Reject a negative withdrawal for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1005"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid withdrawal amount")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1005 New Balance: 5000
# Error: Invalid withdrawal amount

# %% [markdown]
# ### Q6. Catch invalid tenure input for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1006"
try:
    print(account, "New Balance", balance)
    raise ValueError("Invalid tenure")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1006 New Balance 5000
# Error: Invalid tenure

# %% [markdown]
# ### Q7. Use else after pin-format validation for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1007"
try:
    discount = int(account)
except ValueError:
    print("Invalid discount")
else:
    print("Discount:", discount)
# Out:
# Invalid discount

# %% [markdown]
# ### Q8. Use finally to close a session for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1008"
try:
    print(account, "New Balance:", balance)
    raise TypeError("Invalid session")
except TypeError as e:
    print("Error:", e)
finally:
    print("Closing session")
# Out:
# ACC-1008 New Balance: 5000
# Error: Invalid session
# Closing session

# %% [markdown]
# ### Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1009"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid conversion")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1009 New Balance: 5000
# Error: Invalid conversion

# %% [markdown]
# ### Q10. Raise a clear valueerror for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1010"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid value")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1010 New Balance: 5000
# Error: Invalid value

# %% [markdown]
# ### Q11. Parse a deposit amount for banking case 2; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
aacount = "ACC-1011"
try:
    deposit_account = 1500
    print(account, "New Balance:", balance)
    raise TypeError("Invalid deposit amount")
except TypeError as e:
    print("Error:", e)
# Out:
# ACC-1010 New Balance: 5000
# Error: Invalid deposit amount

# %% [markdown]
# ### Q12. Handle a missing account key for banking case 2; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
raw = "ACC-1012"
try:
    print(account, "New Balance:", balance)
    raise KeyError("Invalid account number")
except KeyError as e:
    print("Error:", e)
# Out:
# ACC-1010 New Balance: 5000
# Error: 'Invalid account number'

# %% [markdown]
# ### Q13. Prevent division by zero in average balance for banking case 2; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
raw = "ACC-1013"
try:
    print(account, "New Balance:", balance)
    raise ZeroDivisionError("Division by zero")
except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# ACC-1010 New Balance: 5000
# Error: Division by zero

# %% [markdown]
# ### Q14. Open a transaction file safely for banking case 2; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
raw = "ACC-1014"
try:
    print(account, "New Balance:", balance)
    raise FileNotFoundError("File not found")
except FileNotFoundError as e:
    print("Error:", e)
# Out:
# ACC-1010 New Balance: 5000
# Error: File not found

# %% [markdown]
# ### Q15. Reject a negative withdrawal for banking case 2; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
raw = "ACC-1015"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid withdrawal amount")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1010 New Balance: 5000
# Error: Invalid withdrawal amount

# %% [markdown]
# ### Q16. Catch invalid tenure input for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1016"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid tenure")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1016 New Balance: 5000
# Error: Invalid tenure

# %% [markdown]
# ### Q17. Use else after pin-format validation for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1017"
try:
    discount = int(account)
except ValueError:
    print("Invalid discount")
else:
    print("Discount:", discount)
# Out:
# Invalid discount

# %% [markdown]
# ### Q18. Use finally to close a session for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1018"
try:
    print(account, "New Balance:", balance)
    raise TypeError("Invalid session")
except TypeError as e:
    print("Error:", e)
finally:
    print("Closing session")
# Out:
# ACC-1018 New Balance: 5000
# Error: Invalid session
# Closing session

# %% [markdown]
# ### Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1019"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid conversion")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1019 New Balance: 5000
# Error: Invalid conversion

# %% [markdown]
# ### Q20. Raise a clear valueerror for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1020"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid value")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1020 New Balance: 5000
# Error: Invalid value

# %% [markdown]
# ### Q21. Parse a deposit amount for banking case 3; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1021"
try:
    deposit_account = 1500
    print(account, "New Balance:", balance)
    raise TypeError("Invalid deposit amount")
except TypeError as e:
    print("Error:", e)
# Out:
# ACC-1021 New Balance: 5000
# Error: Invalid deposit amount

# %% [markdown]
# ### Q22. Handle a missing account key for banking case 3; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1022"
try:
    print(account, "New Balance:", balance)
    raise KeyError("Invalid account number")
except KeyError as e:
    print("Error:", e)
# Out:
# ACC-1022 New Balance: 5000
# Error: 'Invalid account number'

# %% [markdown]
# ### Q23. Prevent division by zero in average balance for banking case 3; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1023"
try:
    print(account, "New Balance:", balance)
    raise ZeroDivisionError("Division by zero")
except ZeroDivisionError as e:
    print("Error:", e)
# Out:
# ACC-1023 New Balance: 5000
# Error: Division by zero

# %% [markdown]
# ### Q24. Open a transaction file safely for banking case 3; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1024"
try:
    print(account, "New Balance:", balance)
    raise FileNotFoundError("File not found")
except FileNotFoundError as e:
    print("Error:", e)
# Out:
# ACC-1024 New Balance: 5000
# Error: File not found

# %% [markdown]
# ### Q25. Reject a negative withdrawal for banking case 3; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1025"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid withdrawal amount")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1025 New Balance: 5000
# Error: Invalid withdrawal amount

# %% [markdown]
# ### Q26. Catch invalid tenure input for banking case 3; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1026"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid tenure")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1026 New Balance: 5000
# Error: Invalid tenure

# %% [markdown]
# ### Q27. Use else after pin-format validation for banking case 3; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1027"
try:
    discount = int(account)
except ValueError:
    print("Invalid discount")
else:
    print("Discount:", discount)
# Out:
# Invalid discount

# %% [markdown]
# ### Q28. Use finally to close a session for banking case 3; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1028"
try:
    print(account, "New Balance:", balance)
    raise TypeError("Invalid session")
except TypeError as e:
    print("Error:", e)
finally:
    print("Closing session")
# Out:
# ACC-1028 New Balance: 5000
# Error: Invalid session
# Closing session

# %% [markdown]
# ### Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1029"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid conversion")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1029 New Balance: 5000
# Error: Invalid conversion

# %% [markdown]
# ### Q30. Raise a clear valueerror for banking case 3; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1030"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid value")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1030 New Balance: 5000
# Error: Invalid value

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Create insufficientfundserror for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class InsufficientFundsError(Exception):
    pass
account = "ACC-1031"
try:
    raise InsufficientFundsError("Insufficient funds")
except InsufficientFundsError as e:
    print("Error:", e)
# Out:
# Error: Insufficient funds

# %% [markdown]
# ### Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class InvalidTransactionError(Exception):
    pass
try:
    raise InvalidTransactionError("Invalid transaction")
except InvalidTransactionError as e:
    print("Error:", e)
# Out:
# Error: Invalid transaction

# %% [markdown]
# ### Q33. Process transfers while isolating bad rows for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1033"
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid transfer")
except ValueError as e:
    print("Error:", e)
# Out:
# ACC-1033 New Balance: 5000
# Error: Invalid transfer

# %% [markdown]
# ### Q34. Retry a transient payment gateway for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1034"
try:
    print(account, "New Balance:", balance)
    raise TypeError("Invalid payment gateway")
except TypeError as e:
    print("Error:", e)
# Out:
# ACC-1034 New Balance: 5000
# Error: Invalid payment gateway

# %% [markdown]
# ### Q35. Log failed standing instructions for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import logging
account = "ACC-1035"
logger = logging.getLogger(__name__)
logger.error("Error message")
for handler in logger.handlers:
    logger.removeHandler(handler)
    logger.handlers = []
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid standing instruction")
except ValueError as e:
    print("Error:", e)
# Out:
# ERROR:__main__:Error message
# ACC-1035 New Balance: 5000
# Error: Invalid standing instruction

# %% [markdown]
# ### Q36. Return a structured failure result for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def result(account):
    try:
        print(account, "New Balance:", balance)
        raise TypeError("Invalid result")
    except TypeError as e:
        print("Error:", e)
result(account)
# Out:
# ACC-1035 New Balance: 5000
# Error: Invalid result

# %% [markdown]
# ### Q37. Validate a nested beneficiary record for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1037"
try:
    print(account, "New Balance:", balance)
    raise TypeError("Invalid beneficiary record")
except TypeError as e:
    print("Error:", e)
# Out:
# ACC-1037 New Balance: 5000
# Error: Invalid beneficiary record

# %% [markdown]
# ### Q38. Use a context manager for an audit file for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from pathlib import Path
p=Path('promotion.taxt')
try:
    with p.open(encoding='utf-8') as f:
        print(f.read())
        raise TypeError("Invalid audit file")
except OSError as e:
    print("Promotion file unavailable:", e)
# Out:
# Promotion file unavailable: [Errno 2] No such file or directory: 'promotion.taxt'

# %% [markdown]
# ### Q39. Separate validation and recovery for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def validate_discount(account):
    try:
        rate = int(account)
    except (TypeError, ValueError) as exc:
           raise ValueError("Invalid discount") from exc
    if not 0 <= rate <= 100:
      raise ValueError("Invalid discount")
    return rate
for x in ["10", "20", "30"]:
    try:
        print(validate_discount(x))
    except ValueError as e:
        print("Error:", e)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ### Q40. Collect all kyc validation errors for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1040"
def kyc_validation(account):
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Invalid KYC validation")
    except ValueError as e:
        print("Error:", e)
kyc_validation(account)
# Out:
# ACC-1040 New Balance: 5000
# Error: Invalid KYC validation

# %% [markdown]
# ### Q41. Create insufficientfundserror for banking case 2; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1041"
def insufficient_funds(account):
    if balance < 0:
        raise ValueError("Insufficient funds")
    return balance
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Insufficient funds")
    except ValueError as e:
        print("Error:", e)
insufficient_funds(account)
# Out:
# 5000

# %% [markdown]
# ### Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1042"
def invalid_transaction(account):
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Invalid transaction")
    except ValueError as e:
        print("Error:", e)
invalid_transaction(account)
# Out:
# ACC-1042 New Balance: 5000
# Error: Invalid transaction

# %% [markdown]
# ### Q43. Process transfers while isolating bad rows for banking case 2; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1043"
def process_transfers(account):
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Invalid transfer")
    except ValueError as e:
        print("Error:", e)
process_transfers(account)
# Out:
# ACC-1043 New Balance: 5000
# Error: Invalid transfer

# %% [markdown]
# ### Q44. Retry a transient payment gateway for banking case 2; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1044"
def retry_payment_gateway(account):
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Invalid payment gateway")
    except ValueError as e:
        print("Error:", e)
retry_payment_gateway(account)
# Out:
# ACC-1044 New Balance: 5000
# Error: Invalid payment gateway

# %% [markdown]
# ### Q45. Log failed standing instructions for banking case 2; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1045"
balance = 2000
def log_failed_standing_instructions(account):
    try:
        return {"account": account, "balance": balance}
    except ValueError as e:
        print("Error:", e)
print(log_failed_standing_instructions(account))
# Out:
# {'account': 'ACC-1045', 'balance': 2000}

# %% [markdown]
# ### Q46. Return a structured failure result for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def process_banking_case():
    try:
        # Simulate a business-rule failure
        raise ValueError("Insufficient funds")

    except ValueError as e:
        return {
            "reference": "ACC-1046",
            "status": "FAILED",
            "error_type": "BusinessRuleError",
            "message": str(e)
        }
result = process_banking_case()
print(result)
# Out:
# {'reference': 'ACC-1046', 'status': 'FAILED', 'error_type': 'BusinessRuleError', 'message': 'Insufficient funds'}

# %% [markdown]
# ### Q47. Validate a nested beneficiary record for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def validate_beneficiary(record):
    try:
        beneficiary = record["beneficiary"]
        if not isinstance(beneficiary, dict):
            raise ValueError("Beneficiary must be a nested record")
        if not beneficiary.get("name"):
            raise ValueError("Beneficiary name is required")
        if not beneficiary.get("account_number"):
            raise ValueError("Beneficiary account number is required")
        return {
            "reference": "ACC-1047",
            "status": "SUCCESS",
            "message": "Beneficiary record is valid"
        }

    except (KeyError, ValueError) as e:
        return {
            "reference": "ACC-1047",
            "status": "FAILED",
            "message": str(e)
        }
record = {
    "beneficiary": {
        "name": "Rahul",
        "account_number": "1234567890"
    }
}

result = validate_beneficiary(record)
print(result)
# Out:
# {'reference': 'ACC-1047', 'status': 'SUCCESS', 'message': 'Beneficiary record is valid'}

# %% [markdown]
# ### Q48. Use a context manager for an audit file for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def write_audit(reference, message):
    with open("audit.log", "a") as audit_file:
        audit_file.write(f"{reference}: {message}\n")
    return {
        "reference": reference,
        "status": "SUCCESS",
        "message": "Audit record written successfully"
    }
result = write_audit(
    "ACC-1048",
    "Beneficiary validation completed"
)
print(result)
# Out:
# {'reference': 'ACC-1048', 'status': 'SUCCESS', 'message': 'Audit record written successfully'}

# %% [markdown]
# ### Q49. Separate validation and recovery for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1049"
def validation_and_recovery(account):
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Invalid validation")
    except ValueError as e:
        print("Error:", e)
validation_and_recovery(account)
# Out:
# ACC-1049 New Balance: 2000
# Error: Invalid validation

# %% [markdown]
# ### Q50. Collect all kyc validation errors for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account = "ACC-1050"
def collect_kyc_validation_errors(account):
    try:
        print(account, "New Balance:", balance)
        raise ValueError("Invalid KYC validation")
    except ValueError as e:
        print("Error:", e)
collect_kyc_validation_errors(account)
# Out:
# ACC-1050 New Balance: 2000
# Error: Invalid KYC validation

# %% [markdown]
# ### Q51. Create insufficientfundserror for banking case 3; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class InsufficientFundsError(Exception):
    pass
def withdraw(reference, balance, amount):
    try:
        if amount > balance:
            raise InsufficientFundsError(
                f"Insufficient funds: balance={balance}, requested={amount}"
            )
        balance -= amount
        return {
            "reference": reference,
            "status": "SUCCESS",
            "balance": balance
        }
    except InsufficientFundsError as e:
        return {
            "reference": reference,
            "status": "FAILED",
            "error_type": "InsufficientFundsError",
            "message": str(e)
        }
result = withdraw("ACC-1051", 5000, 7500)
print(result)
# Out:
# {'reference': 'ACC-1051', 'status': 'FAILED', 'error_type': 'InsufficientFundsError', 'message': 'Insufficient funds: balance=5000, requested=7500'}

# %% [markdown]
# ### Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class InvalidTransactionError(Exception):
    pass
def process_transaction(reference, amount):
    try:
        if amount < 0:
            raise InvalidTransactionError(
                f"Invalid transaction: amount={amount}"
            )
            return {
                "reference": reference,
                "status": "SUCCESS",
                "message": "Transaction processed successfully"
            }
    except InvalidTransactionError as e:
            return {
                    "reference": reference,
                    "status": "FAILED",
                    "error_type": "InvalidTransactionError",
                    "message": str(e)
                }
result = process_transaction("ACC-1052", -500)
print(result)
# Out:
# {'reference': 'ACC-1052', 'status': 'FAILED', 'error_type': 'InvalidTransactionError', 'message': 'Invalid transaction: amount=-500'}

# %% [markdown]
# ### Q53. Process transfers while isolating bad rows for banking case 3; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class TransferError(Exception):
    pass
def process_transfers(reference, amount):
    try:
        if amount < 0:
            raise TransferError(
                f"Invalid transfer: amount={amount}"
            )
    except TransferError as e:
        return {
            "reference": reference,
            "status": "FAILED",
            "error_type": "TransferError",
            "message": str(e)
        }
    return {
        "reference": reference,
        "status": "SUCCESS",
        "message": "Transfers processed successfully"
    }
result = process_transfers("ACC-1053", -500)
print(result)
# Out:
# {'reference': 'ACC-1053', 'status': 'FAILED', 'error_type': 'TransferError', 'message': 'Invalid transfer: amount=-500'}

# %% [markdown]
# ### Q54. Retry a transient payment gateway for banking case 3; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def retry_payment_gateway(reference, amount):
    try:
        if amount < 0:
            raise ValueError(
                f"Invalid payment gateway: amount={amount}"
            )
            return {
                "reference": reference,
                "status": "SUCCESS",
                "message": "Payment gateway processed successfully"
            }
    except ValueError as e:
        return {
            "reference": reference,
            "status": "FAILED",
            "error_type": "ValueError",
            "message": str(e)
        }
        result = retry_payment_gateway("ACC-1054", -500)
print(result)
# Out:
# {'reference': 'ACC-1053', 'status': 'FAILED', 'error_type': 'TransferError', 'message': 'Invalid transfer: amount=-500'}

# %% [markdown]
# ### Q55. Log failed standing instructions for banking case 3; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_failed_standing_instructions(reference, message):
    with open("audit.log", "a") as audit_file:
        audit_file.write(f"{reference}: {message}\n")
    return {
        "reference": reference,
        "status": "SUCCESS",
        "message": "Audit record written successfully"
    }
result = log_failed_standing_instructions(
    "ACC-1055",
    "Standing instructions failed"
)
print(result)
# Out:
# {'reference': 'ACC-1055', 'status': 'SUCCESS', 'message': 'Audit record written successfully'}

# %% [markdown]
# ### Q56. Return a structured failure result for banking case 3; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BusinessRuleError(Exception):
    pass
def process_banking_case():
    try:
        # Simulate a business-rule failure
        raise ValueError("Insufficient funds")

    except ValueError as e:
        return {
            "reference": "ACC-1056",
            "status": "FAILED",
            "error_type": "BusinessRuleError",
            "message": str(e)
        }
result = process_banking_case()
print(result)
# Out:
# {'reference': 'ACC-1056', 'status': 'FAILED', 'error_type': 'BusinessRuleError', 'message': 'Insufficient funds'}

# %% [markdown]
# ### Q57. Validate a nested beneficiary record for banking case 3; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BeneficiaryValidationError(Exception):
    pass


beneficiary = {
    "account": {
        "reference": "ACC-1057",
        "beneficiary": {
            "name": "Ravi Kumar",
            "account_number": "1234567890",
            "bank": "ABC Bank"
        }
    }
}

try:
    account = beneficiary["account"]
    details = account["beneficiary"]

    if not details.get("name"):
        raise BeneficiaryValidationError("Beneficiary name is missing")

    if not details.get("account_number"):
        raise BeneficiaryValidationError("Beneficiary account number is missing")

    if not details.get("bank"):
        raise BeneficiaryValidationError("Beneficiary bank is missing")

    print("Beneficiary validation successful")
    print("Reference:", account["reference"])
    print("Beneficiary:", details["name"])

except KeyError as e:
    print("Validation failed: Missing field", e)

except BeneficiaryValidationError as e:
    print("Validation failed:", e)
# Out:
# Beneficiary validation successful
# Reference: ACC-1057
# Beneficiary: Ravi Kumar

# %% [markdown]
# ### Q58. Use a context manager for an audit file for banking case 3; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
audit_file = "banking_audit.txt"
reference = "ACC-1058"
with open(audit_file, "a") as file:
    file.write(f"Audit record: {reference} - Beneficiary validation completed\n")
print("Audit record written successfully.")
print("Reference:", reference)
# Out:
# Audit record written successfully.
# Reference: ACC-1058

# %% [markdown]
# ### Q59. Separate validation and recovery for banking case 3; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ValidationError(Exception):
    pass
def validate(data):
    if not data["name"]:
        raise ValidationError("Name is missing")
    print("Validation successful")
def recover(reference, error):
    print("Recovery for", reference)
    print("Error:", error)
reference = "ACC-1059"
data = {
    "name": "Ravi"
}
try:
    validate(data)
except ValidationError as e:
    recover(reference, e)
# Out:
# Validation successful

# %% [markdown]
# ### Q60. Collect all kyc validation errors for banking case 3; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class KYCError(Exception):
    pass
reference = "ACC-1060"
kyc = {
    "name": "",
    "pan": "",
    "address": "Hyderabad"
}
errors = []
if not kyc["name"]:
    errors.append("Name is missing")
if not kyc["pan"]:
    errors.append("PAN is missing")
if not kyc["address"]:
    errors.append("Address is missing")
if errors:
    print(reference, "KYC validation failed")
    for error in errors:
        print("-", error)
else:
    print(reference, "KYC validation successful")
# Out:
# ACC-1060 KYC validation failed
# - Name is missing
# - PAN is missing

# %% [markdown]
# ### Q61. Create insufficientfundserror for banking case 4; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Insufficient_Funds_Error(Exception):
    pass
balance = 5000
withdraw = 6000
reference = "ACC-1061"
try:
    if withdraw > balance:
        raise InsufficientFundsError("Insufficient funds")
    balance -= withdraw
    print("Withdrawal successful")
except InsufficientFundsError as e:
    print(reference, ":", e)
# Out:
# ACC-1061 : Insufficient funds

# %% [markdown]
# ### Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class chain_invalidation_error(Exception):
    pass
reference = "ACC-1062"
amount = -500
try:
    if amount < 0:
        raise chain_invalidation_error("Invalid transaction")
        print("Transaction processed successfully")
except chain_invalidation_error as e:
    print(reference, ":", e)
# Out:
# ACC-1062 : Invalid transaction

# %% [markdown]
# ### Q63. Process transfers while isolating bad rows for banking case 4; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class TransferError(Exception):
    pass
transfers = [
    ("ACC-1063", 1000),
    ("ACC-1064", "bad"),
    ("ACC-1065", 2000)
]
for reference, amount in transfers:
    try:
        amount = float(amount)
        print(reference, "Transfer successful:", amount)
    except (ValueError, TypeError):
        print(reference, "Bad row - skipped")
# Out:
# ACC-1063 Transfer successful: 1000.0
# ACC-1064 Bad row - skipped
# ACC-1065 Transfer successful: 2000.0

# %% [markdown]
# ### Q64. Retry a transient payment gateway for banking case 4; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class GatewayError(Exception):
    pass

reference = "ACC-1064"

for attempt in range(1, 4):
    try:
        if attempt < 3:
            raise GatewayError("Gateway temporarily unavailable")

        print(reference, "Payment successful")
        break

    except GatewayError as e:
        print(reference, "Attempt", attempt, "failed:", e)
# Out:
# ACC-1064 Attempt 1 failed: Gateway temporarily unavailable
# ACC-1064 Attempt 2 failed: Gateway temporarily unavailable
# ACC-1064 Payment successful

# %% [markdown]
# ### Q65. Log failed standing instructions for banking case 4; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class log_failed_standing_instructions(Exception):
    pass
reference = "ACC-1065"
message = "Standing instructions failed"
with open("audit.log", "a") as audit_file:
    audit_file.write(f"{reference}: {message}\n")
print("Audit record written successfully.")
print("Reference:", reference)
print("Message:", message)
# Out:
# Audit record written successfully.
# Reference: ACC-1065
# Message: Standing instructions failed

# %% [markdown]
# ### Q66. Return a structured failure result for banking case 4; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class return_structured_failure(Exception):
    pass
reference = "ACC-1066"
try:
    raise return_structured_failure("Business rule violation")
except return_structured_failure as e:
    result = {
        "reference": reference,
        "status": "FAILED",
        "error_type": "return_structured_failure",
        "message": str(e)
    }
    print(result)
# Out:
# {'reference': 'ACC-1066', 'status': 'FAILED', 'error_type': 'return_structured_failure', 'message': 'Business rule violation'}

# %% [markdown]
# ### Q67. Validate a nested beneficiary record for banking case 4; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ValidationError(Exception):
    pass
reference = "ACC-1067"
data = {
    "account": {
        "beneficiary": {
            "name": "Ravi",
            "bank": "ABC Bank"
        }
    }
}

try:
    beneficiary = data["account"]["beneficiary"]
    if not beneficiary["name"] or not beneficiary["bank"]:
        raise ValidationError("Invalid beneficiary")
    print(reference, "Beneficiary validation successful")
except (KeyError, ValidationError) as e:
    print(reference, "Validation failed:", e)
# Out:
# ACC-1067 Beneficiary validation successful

# %% [markdown]
# ### Q68. Use a context manager for an audit file for banking case 4; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1068"

with open("audit.txt", "a") as file:
    file.write(f"{reference} - Audit record completed\n")

print(reference, "Audit record saved successfully")
# Out:
# ACC-1068 Audit record saved successfully

# %% [markdown]
# ### Q69. Separate validation and recovery for banking case 4; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class ValidationException(Exception):
    pass
reference = "ACC-1069"
data = {
    "name": "Ravi"
}
try:
    if not data["name"]:
        raise ValidationException("Name is missing")
    print("Validation successful")
except ValidationException as e:
    print(reference, ":", e)
# Out:
# Validation successful

# %% [markdown]
# ### Q70. Collect all kyc validation errors for banking case 4; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class KYCError(Exception):
    pass
reference = "ACC-1070"
kyc = {
    "name": "",
    "pan": "",
    "address": "Hyderabad"
}
errors = []
if not kyc["name"]:
    errors.append("Name is missing")
if not kyc["pan"]:
    errors.append("PAN is missing")
if not kyc["address"]:
    errors.append("Address is missing")
if errors:
    print(reference, "KYC validation failed")
    for error in errors:
        print("-", error)
else:
    print(reference, "KYC validation successful")
# Out:
# ACC-1070 KYC validation failed
# - Name is missing
# - PAN is missing

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design a banking exception hierarchy for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):
    pass
class AccountError(BankingError):
    pass
class InsufficientFundsError(AccountError):
    pass
class InvalidAccountError(AccountError):
    pass
reference = "ACC-1071"
try:
    raise InsufficientFundsError("Insufficient balance")
except InsufficientFundsError as e:
    print(reference, ":", e)
except AccountError as e:
    print(reference, "Account error:", e)
# Out:
# ACC-1071 : Insufficient balance

# %% [markdown]
# ### Q72. Make a transfer rollback-safe for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
balance = 5000
reference = "ACC-1072"
amount = 2000
try:
    old_balance = balance
    balance -= amount
    raise Exception("Transfer failed")
except Exception as e:
    balance = old_balance
    print(reference, "Transfer rolled back")
    print("Balance:", balance)
# Out:
# ACC-1072 Transfer rolled back
# Balance: 5000

# %% [markdown]
# ### Q73. Preserve causes across service layers for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):
    pass
def payment_service(reference):
    try:
        raise ValueError("Invalid payment amount")
    except ValueError as e:
        raise BankingError(f"Payment failed for {reference}") from e
try:
    payment_service("ACC-1073")
except BankingError as e:
    print(e)
    print("Original cause:", e.__cause__)
# Out:
# Payment failed for ACC-1073
# Original cause: Invalid payment amount

# %% [markdown]
# ### Q74. Implement bounded exponential retry for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import time
reference = "ACC-1074"
for attempt in range(1, 4):
    try:
        if attempt < 3:
            raise ConnectionError("Gateway temporarily unavailable")
        print(reference, "Payment successful")
        break
    except ConnectionError as e:
        print(reference, "Attempt", attempt, "failed")
        if attempt == 3:
            print("Retry limit reached")
            break
        time.sleep(2 ** (attempt - 1))
# Out:
# ACC-1074 Attempt 1 failed
# ACC-1074 Attempt 2 failed
# ACC-1074 Payment successful

# %% [markdown]
# ### Q75. Create a transaction context manager for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transaction:
    def __init__(self, reference):
        self.reference = reference
        self.balance = 1000
    def withdraw(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient balance")
        self.balance -= amount
        print(self.reference, "Withdrawal successful")

transaction = Transaction("ACC-1075")
try:
    transaction.withdraw(2000)
except ValueError as e:
    print(transaction.reference, ":", e)
    print("Balance:", transaction.balance)
# Out:
# ACC-1075 : Insufficient balance
# Balance: 1000

# %% [markdown]
# ### Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
payment_events = [
    ("ACC-1076", "success"),
    ("ACC-1077", "failed"),
    ("ACC-1078", "success")
]
dead_letter_queue = []
for reference, status in payment_events:
    try:
        if status == "failed":
            raise Exception("Payment processing failed")
        print(reference, "Payment processed")
    except Exception as e:
        dead_letter_queue.append((reference, str(e)))
        print(reference, "Moved to DLQ")
print("Dead-Letter Queue:", dead_letter_queue)
# Out:
# ACC-1076 Payment processed
# ACC-1077 Moved to DLQ
# ACC-1078 Payment processed
# Dead-Letter Queue: [('ACC-1077', 'Payment processing failed')]

# %% [markdown]
# ### Q77. Make batch settlement failure-isolated for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
settlements = [
    ("ACC-1077", 1000),
    ("ACC-1078", "bad"),
    ("ACC-1079", 2000)
]

for reference, amount in settlements:
    try:
        amount = float(amount)
        print(reference, "Settlement successful:", amount)
    except (ValueError, TypeError):
        print(reference, "Settlement failed - skipped")
# Out:
# ACC-1077 Settlement successful: 1000.0
# ACC-1078 Settlement failed - skipped
# ACC-1079 Settlement successful: 2000.0

# %% [markdown]
# ### Q78. Report exact paths in nested statements for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1078"

data = {
    "account": {
        "customer": {
            "beneficiary": {
                "name": "Ravi"
            }
        }
    }
}

try:
    name = data["account"]["customer"]["beneficiary"]["name"]
    print(reference, "Path: account -> customer -> beneficiary -> name")
    print("Value:", name)

except KeyError as e:
    print(reference, "Missing path:", e)
# Out:
# ACC-1078 Path: account -> customer -> beneficiary -> name
# Value: Ravi

# %% [markdown]
# ### Q79. Design idempotent recovery after timeout for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
processed = set()
reference = "ACC-1079"

def recover_payment(reference):
    if reference in processed:
        print(reference, "Already recovered - no duplicate payment")
    else:
        processed.add(reference)
        print(reference, "Payment recovered successfully")
recover_payment(reference)
recover_payment(reference)
# Out:
# ACC-1079 Payment recovered successfully
# ACC-1079 Already recovered - no duplicate payment

# %% [markdown]
# ### Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transactions = [
    ("ACC-1080", 1000),
    ("ACC-1081", 2000),
    ("ACC-1082", "bad")
]
for reference, amount in transactions:
    try:
        amount = float(amount)
        print(reference, "Reconciled:", amount)
    except (ValueError, TypeError) as e:
        print(reference, "Reconciliation failed:", e)
print("Reconciliation completed")
# Out:
# ACC-1080 Reconciled: 1000.0
# ACC-1081 Reconciled: 2000.0
# ACC-1082 Reconciliation failed: could not convert string to float: 'bad'
# Reconciliation completed

# %% [markdown]
# ### Q81. Design a banking exception hierarchy for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):
    pass
class AccountError(BankingError):
    pass
class InsufficientFundsError(AccountError):
    pass
class InvalidAccountError(AccountError):
    pass
    reference = "ACC-1081"
try:
    raise InsufficientFundsError("Insufficient balance")
except InsufficientFundsError as e:
    print(reference, ":", e)
except AccountError as e:
    print(reference, "Account error:", e)
# Out:
# ACC-1082 : Insufficient balance

# %% [markdown]
# ### Q82. Make a transfer rollback-safe for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1082"
balance = 5000
amount = 2000
try:
    old_balance = balance
    balance -= amount
    raise Exception("Transfer failed")
except Exception as e:
    balance = old_balance
    print(reference, "Transfer rolled back")
    print("Balance:", balance)
# Out:
# ACC-1082 Transfer rolled back
# Balance: 5000

# %% [markdown]
# ### Q83. Preserve causes across service layers for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):
    pass
def payment_service(reference):
    try:
        raise ValueError("Invalid payment amount")
    except ValueError as e:
        raise BankingError(f"Payment failed for {reference}") from e
try:
    payment_service("ACC-1083")
except BankingError as e:
    print(e)
    print("Original cause:", e.__cause__)
# Out:
# Payment failed for ACC-1083
# Original cause: Invalid payment amount

# %% [markdown]
# ### Q84. Implement bounded exponential retry for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1084"
for attempt in range(1, 4):
    try:
        if attempt < 3:
            raise ConnectionError("Gateway temporarily unavailable")
        print(reference, "Payment successful")
        break
    except ConnectionError as e:
        print(reference, "Attempt", attempt, "failed")
# Out:
# ACC-1084 Attempt 1 failed
# ACC-1084 Attempt 2 failed
# ACC-1084 Payment successful

# %% [markdown]
# ### Q85. Create a transaction context manager for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transaction:
    def __init__(self, reference):
        self.reference = reference
        self.balance = 1000
    def withdraw(self, amount):
        if amount > self.balance:
            raise ValueError("Insufficient balance")
            self.balance -= amount
            print(self.reference, "Withdrawal successful")
            transaction = Transaction("ACC-1085")
try:
    transaction.withdraw(2000)
except ValueError as e:
    print(transaction.reference, ":", e)
    print("Balance:", transaction.balance)
# Out:
# ACC-1075 : Insufficient balance
# Balance: 1000

# %% [markdown]
# ### Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1086"
payment_events = [
    ("ACC-1086", "success"),
    ("ACC-1087", "failed"),
    ("ACC-1088", "success")
]
dead_letter_queue = []
for reference, status in payment_events:
    try:
        if status == "failed":
            raise Exception("Payment processing failed")
        print(reference, "Payment processed")
    except Exception as e:
        dead_letter_queue.append((reference, str(e)))
        print(reference, "Moved to DLQ")
print("Dead-Letter Queue:", dead_letter_queue)
# Out:
# ACC-1086 Payment processed
# ACC-1087 Moved to DLQ
# ACC-1088 Payment processed
# Dead-Letter Queue: [('ACC-1087', 'Payment processing failed')]

# %% [markdown]
# ### Q87. Make batch settlement failure-isolated for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
settlements = [
    ("ACC-1087", 1000),
    ("ACC-1088", "bad"),
    ("ACC-1089", 2000)
]
for reference, amount in settlements:
    try:
        amount = float(amount)
        print(reference, "Settlement successful:", amount)
    except (ValueError, TypeError):
        print(reference, "Settlement failed - skipped")
        print("Balance:", transaction.balance)
        print("Balance:", transaction.balance)
print("Reconciliation completed")
# Out:
# ACC-1087 Settlement successful: 1000.0
# ACC-1088 Settlement failed - skipped
# Balance: 1000
# Balance: 1000
# ACC-1089 Settlement successful: 2000.0
# Reconciliation completed

# %% [markdown]
# ### Q88. Report exact paths in nested statements for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
settlements = [
    ("ACC-1087", 1000),
    ("ACC-1088", "bad"),
    ("ACC-1089", 2000)
]

for reference, amount in settlements:
    try:
        amount = float(amount)
        print(reference, "Settlement successful:", amount)
    except (ValueError, TypeError):
        print(reference, "Settlement failed - skipped")
# Out:
# ACC-1087 Settlement successful: 1000.0
# ACC-1088 Settlement failed - skipped
# ACC-1089 Settlement successful: 2000.0

# %% [markdown]
# ### Q89. Design idempotent recovery after timeout for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
processed = set()
reference = "ACC-1089"

def recover_payment(reference):
    if reference in processed:
        print(reference, "Already recovered")
    else:
        processed.add(reference)
        print(reference, "Payment recovered")

recover_payment(reference)
recover_payment(reference)
# Out:
# ACC-1089 Payment recovered
# ACC-1089 Already recovered

# %% [markdown]
# ### Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1090"
transactions = [
    ("ACC-1080", 1000),
    ("ACC-1081", 2000),
    ("ACC-1082", "bad")
]
for reference, amount in transactions:
    try:
        amount = float(amount)
        print(reference, "Reconciled:", amount)
    except (ValueError, TypeError) as e:
        print(reference, "Reconciliation failed:", e)
print("Reconciliation completed")
# Out:
# ACC-1080 Reconciled: 1000.0
# ACC-1081 Reconciled: 2000.0
# ACC-1082 Reconciliation failed: could not convert string to float: 'bad'
# Reconciliation completed

# %% [markdown]
# ### Q91. Design a banking exception hierarchy for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):
    pass
class AccountError(BankingError):
    pass
class InsufficientFundsError(AccountError):
    pass
class InvalidAccountError(AccountError):
    pass
    reference = "ACC-1091"
try:
    raise InsufficientFundsError("Insufficient balance")
except InsufficientFundsError as e:
    print(reference, ":", e)
except AccountError as e:
    print(reference, "Account error:", e)
# Out:
# ACC-1082 : Insufficient balance

# %% [markdown]
# ### Q92. Make a transfer rollback-safe for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1092"
balance = 5000
amount = 2000
try:
    old_balance = balance
    balance -= amount
    raise Exception("Transfer failed")
except Exception as e:
    balance = old_balance
    print(reference, "Transfer rolled back")
    print("Balance:", balance)
# Out:
# ACC-1092 Transfer rolled back
# Balance: 5000

# %% [markdown]
# ### Q93. Preserve causes across service layers for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):
    pass
def payment_service(reference):
    try:
        raise ValueError("Invalid payment amount")
    except ValueError as e:
        raise BankingError(f"Payment failed for {reference}") from e
try:
    payment_service("ACC-1093")
except BankingError as e:
    print(e)
    print("Original cause:", e.__cause__)
# Out:
# Payment failed for ACC-1093
# Original cause: Invalid payment amount

# %% [markdown]
# ### Q94. Implement bounded exponential retry for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference = "ACC-1094"
for attempt in range(1, 4):
    try:
        if attempt < 3:
            raise ConnectionError("Gateway timeout")
        print(reference, "Payment successful")
        break
    except ConnectionError:
        print(reference, "Attempt", attempt, "failed")
        if attempt == 3:
            print("Retry limit reached")
            break
        time.sleep(2 ** (attempt - 1))
# Out:
# ACC-1094 Attempt 1 failed
# ACC-1094 Attempt 2 failed
# ACC-1094 Payment successful

# %% [markdown]
# ### Q95. Create a transaction context manager for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution
class Transaction:
    def __enter__(self):
        print("Transaction started")
        return self
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print("Transaction rolled back")
        else:
            print("Transaction committed")
reference = "ACC-1095"
try:
    with Transaction():
        print(reference, "Processing transfer")
        raise Exception("Transfer failed")
except Exception as e:
    print(reference, "Error:", e)
# Out:
# Transaction started
# ACC-1095 Processing transfer
# Transaction rolled back
# ACC-1095 Error: Transfer failed

# %% [markdown]
# ### Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transactions = [
    ("ACC-1096", "success"),
    ("ACC-1097", "failed"),
    ("ACC-1098", "success")
]
dead_letter_queue = []
for reference, status in transactions:
    try:
        if status == "failed":
            raise Exception("Payment processing failed")
        print(reference, "Payment processed")
    except Exception as e:
        dead_letter_queue.append((reference, str(e)))
        print(reference, "Moved to DLQ")
print("Dead-Letter Queue:", dead_letter_queue)
# Out:
# ACC-1096 Payment processed
# ACC-1097 Moved to DLQ
# ACC-1098 Payment processed
# Dead-Letter Queue: [('ACC-1097', 'Payment processing failed')]

# %% [markdown]
# ### Q97. Make batch settlement failure-isolated for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transactions = [
    ("ACC-1097", 1000),
    ("ACC-1098", "bad"),
    ("ACC-1099", 2000)
]
for reference, amount in transactions:
    try:
        amount = float(amount)
        print(reference, "Settlement successful:", amount)
    except (ValueError, TypeError):
        print(reference, "Settlement failed - skipped")
        print("Balance:", transaction.balance)
        print("Balance:", transaction.balance)
print("Reconciliation completed")
# Out:
# ACC-1097 Settlement successful: 1000.0
# ACC-1098 Settlement failed - skipped
# Balance: 1000
# Balance: 1000
# ACC-1099 Settlement successful: 2000.0
# Reconciliation completed

# %% [markdown]
# ### Q98. Report exact paths in nested statements for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transactions = [
    ("ACC-1097", 1000),
    ("ACC-1098", "bad"),
    ("ACC-1099", 2000)
]
for reference, amount in transactions:
    try:
        amount = float(amount)
        print(reference, "Settlement successful:", amount)
    except (ValueError, TypeError) as e:
        print(reference, "Settlement failed:", e)
print("Reconciliation completed")
# Out:
# ACC-1097 Settlement successful: 1000.0
# ACC-1098 Settlement failed: could not convert string to float: 'bad'
# ACC-1099 Settlement successful: 2000.0
# Reconciliation completed

# %% [markdown]
# ### Q99. Design idempotent recovery after timeout for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
processed = set()
reference = "ACC-1099"
try:
    if reference in processed:
        raise Exception("Already processed")
    processed.add(reference)
    print(reference, "Payment recovered")
except Exception as e:
    print(reference, e)
try:
    if reference in processed:
        raise Exception("Already processed")
    processed.add(reference)
    print(reference, "Payment recovered")
except Exception as e:
    print(reference, "No duplicate payment:", e)
    print("Balance:", transaction.balance)
# Out:
# ACC-1099 Payment recovered
# ACC-1099 No duplicate payment: Already processed
# Balance: 1000

# %% [markdown]
# ### Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transactions = [
    ("ACC-1100", 1000),
    ("ACC-1101", "bad"),
    ("ACC-1102", 2000)
]
for ref, amount in transactions:
    try:
        amount = float(amount)
        print(ref, "Reconciled successfully:", amount)
    except (ValueError, TypeError):
        print(ref, "Reconciliation failed - skipped")
print("Pipeline completed")
# Out:
# ACC-1100 Reconciled successfully: 1000.0
# ACC-1101 Reconciliation failed - skipped
# ACC-1102 Reconciled successfully: 2000.0
# Pipeline completed
