# %% [markdown]
# # Banking Assignment — Functions, Lambda, map, filter, and reduce (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice function design, parameters, returns, scope, docstrings, type hints, pure functions, higher-order functions, closures, decorators, recursion, lambda expressions, map, filter, reduce, pipelines, and testing. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Write a function for line total for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from functools import reduce
def line_total(amount: float, qty: int = 1) -> float:
    """Return total transaction amount."""
    return round(amount * qty, 2)
transaction_amounts = [1000, 2500, 5000]
print("Reference: ACC-1001")
print("Line Total:", line_total(transaction_amounts[0], 2))
print("Amounts with Charge:", list(map(lambda a: round(a * 1.05, 2), transaction_amounts)))
print("High Value Transactions:", list(filter(lambda a: a >= 2500, transaction_amounts)))
print("Total Transactions:", reduce(lambda a, b: a + b, transaction_amounts, 0))
# Out:
# Reference: ACC-1001
# Line Total: 2000
# Amounts with Charge: [1050.0, 2625.0, 5250.0]
# High Value Transactions: [2500, 5000]
# Total Transactions: 8500

# %% [markdown]
# ### Q2. Return a discounted amount for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from functools import reduce
def line_total(amount: float, qty: int = 1) -> float:
    """Return total transaction amount."""
    return round(amount * qty, 2)
dicount = 0.05
transaction_amounts = [1000, 2500, 5000]
print("Reference: ACC-1002")
print("Line Total:", line_total(transaction_amounts[0], 2))
print("Amounts with Charge:", list(map(lambda a: round(a * 1.05, 2), transaction_amounts)))
print("High Value Transactions:", list(filter(lambda a: a >= 2500, transaction_amounts)))
print("Total Transactions:", reduce(lambda a, b: a + b, transaction_amounts, 0))
print("Discounted Amounts:", list(map(lambda a: round(a * (1 - dicount), 2), transaction_amounts)))
# Out:
# Reference: ACC-1002
# Line Total: 2000
# Amounts with Charge: [1050.0, 2625.0, 5250.0]
# High Value Transactions: [2500, 5000]
# Total Transactions: 8500
# Discounted Amounts: [950.0, 2375.0, 4750.0]

# %% [markdown]
# ### Q3. Use a default tax rate for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from functools import reduce
def line_total(amount: float, qty: int = 1) -> float:
    """Return total transaction amount."""
    return round(amount * qty, 2)
dicount = 0.0
tax_rate = 0.0
transaction_amounts = [1000, 2500, 5000]
print("Reference: ACC-1003")
print("Line Total:", line_total(transaction_amounts[0], 2))
print("Amounts with Charge:", list(map(lambda a: round(a * 1.05, 2), transaction_amounts)))
print("High Value Transactions:", list(filter(lambda a: a >= 2500, transaction_amounts)))
print("Total Transactions:", reduce(lambda a, b: a + b, transaction_amounts, 0))
print("Discounted Amounts:", list(map(lambda a: round(a * (1 - dicount), 2), transaction_amounts)))
print("Taxed Amounts:", list(map(lambda a: round(a * (1 + tax_rate), 2), transaction_amounts)))
# Out:
# Reference: ACC-1003
# Line Total: 2000
# Amounts with Charge: [1050.0, 2625.0, 5250.0]
# High Value Transactions: [2500, 5000]
# Total Transactions: 8500
# Discounted Amounts: [1000.0, 2500.0, 5000.0]
# Taxed Amounts: [1000.0, 2500.0, 5000.0]

# %% [markdown]
# ### Q4. Accept keyword arguments for a account for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def account(**details):
    print("Reference:", details.get("reference"))
    print("Account Number:", details.get("account_number"))
    print("Account Holder:", details.get("name"))
    print("Balance:", details.get("balance"))
account(
    reference="ACC-1004",
    account_number="1234567890",
    name="Jayalakshmi",
    balance=50000
)
# Out:
# Reference: ACC-1004
# Account Number: 1234567890
# Account Holder: Jayalakshmi
# Balance: 50000

# %% [markdown]
# ### Q5. Return multiple inventory values for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def inventory_values():
    account_type = "Savings"
    available_balance = 50000
    transaction_count = 25
    return account_type, available_balance, transaction_count
reference = "ACC-1005"
account_type, balance, transactions = inventory_values()
print("Reference:", reference)
print("Account Type:", account_type)
print("Available Balance:", balance)
print("Transaction Count:", transactions)
# Out:
# Reference: ACC-1005
# Account Type: Savings
# Available Balance: 50000
# Transaction Count: 25

# %% [markdown]
# ### Q6. Write a account docstring for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Banking Case 1 - ACC-1006
def account(name, balance):
    return f"Account Holder: {name}, Balance: ₹{balance}"
reference = "ACC-1006"
print("Reference:", reference)
print(account("Jayalakshmi", 50000))
# Out:
# Reference: ACC-1006
# Account Holder: Jayalakshmi, Balance: ₹50000

# %% [markdown]
# ### Q7. Add type hints to a amount function for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def amount(value: float, charge: float = 0.0) -> float:
    """Return the total banking amount including charges."""
    return value + charge
reference = "ACC-1007"
result = amount(5000.0, 50.0)
print("Reference:", reference)
print("Total Amount:", result)
# Out:
# Reference: ACC-1007
# Total Amount: 5050.0

# %% [markdown]
# ### Q8. Use *args to total purchases for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def total_purchases(*purchases):
    total = 0
    for purchase in purchases:
        total += purchase
    return total
reference = "ACC-1008"
purchases = [1000, 2500, 5000]
print("Reference:", reference)
print("Total Purchases:", total_purchases(*purchases))
# Out:
# Reference: ACC-1008
# Total Purchases: 8500

# %% [markdown]
# ### Q9. Use **kwargs for account attributes for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def account(**details):
    for key, value in details.items():
        print(f"{key}: {value}")
reference = "ACC-1009"
print("Reference:", reference)
account(name="Jayalakshmi", balance=50000)
print("Account Type:", account_type)
print("Available Balance:", balance)
print("Transaction Count:", transactions)
# Out:
# Reference: ACC-1009
# name: Jayalakshmi
# balance: 50000
# Account Type: Savings
# Available Balance: 50000
# Transaction Count: 25

# %% [markdown]
# ### Q10. Create a one-line amount lambda for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
# Banking Case 1 - ACC-1010
def amount(balance, deposit):
    return balance + deposit
amount = lambda balance, deposit: balance + deposit
reference = "ACC-1010"
result = amount(5000, 2000)
print("Reference:", reference)
print("Updated Amount:", result)
# Out:
# Reference: ACC-1010
# Updated Amount: 7000

# %% [markdown]
# ### Q11. Map amounts to tax-inclusive amounts for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def map_amounts_to_tax_inclusive_amounts(amounts):
    return list(map(lambda amount: amount * 1.1, amounts))
print("Reference: ACC-1011")
print("Amounts:", [1000, 2500, 5000])
print("Tax-Inclusive Amounts:", map_amounts_to_tax_inclusive_amounts([1000, 2500, 5000]))
# Out:
# Reference: ACC-1011
# Amounts: [1000, 2500, 5000]
# Tax-Inclusive Amounts: [1100.0, 2750.0, 5500.0]

# %% [markdown]
# ### Q12. Filter in-balance accounts for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def filter_in_balance_accounts(accounts):
    return list(filter(lambda account: account["balance"] < 0, accounts))
accounts = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": -25000},
    {"account_number": "1122334455", "balance": 20000}
    ]
print("Reference: ACC-1012")
print("In-Balance Accounts:", filter_in_balance_accounts(accounts))
# Out:
# Reference: ACC-1012
# In-Balance Accounts: [{'account_number': '0987654321', 'balance': -25000}]

# %% [markdown]
# ### Q13. Reduce a basket to its total for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def reduce_basket_to_total(basket):
    return reduce(lambda total, item: total + item["price"], basket, 0)
basket = [
    {"item": "Apple", "price": 1.0},
    {"item": "Banana", "price": 0.5},
    {"item": "Orange", "price": 0.75}
    ]
print("Reference: ACC-1013")
print("Basket:", basket)
print("Total:", reduce_basket_to_total(basket))
# Out:
# Reference: ACC-1013
# Basket: [{'item': 'Apple', 'price': 1.0}, {'item': 'Banana', 'price': 0.5}, {'item': 'Orange', 'price': 0.75}]
# Total: 2.25

# %% [markdown]
# ### Q14. Demonstrate local scope for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def calculate_balance():
    balance = 5000
    print("Balance inside function:", balance)
reference = "ACC-1014"
print("Reference:", reference)
calculate_balance()
# Out:
# Reference: ACC-1014
# Balance inside function: 5000

# %% [markdown]
# ### Q15. Write a predicate for premium accounts for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def is_premium_account(account):
    return account["balance"] >= 100000
accounts = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1015")
print("Premium Accounts:", list(filter(is_premium_account, accounts)))
# Out:
# Reference: ACC-1015
# Premium Accounts: [{'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ### Q16. Write a function for line total for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def line_total(amount: float, qty: int = 1) -> float:
    """Return total transaction amount."""
    return round(amount * qty, 2)
amount = [1000, 2000, 5000]
print("Reference: ACC-1016")
print("Line Total:", line_total(amount[0], 2))
print("Amounts with Charge:", list(map(lambda a: round(a * 1.05, 2), amount)))
print("High Value Transactions:", list(filter(lambda a: a >= 2500, amount)))
print("Total Transactions:", reduce(lambda a, b: a + b, amount, 0))
# Out:
# Reference: ACC-1016
# Line Total: 2000
# Amounts with Charge: [1050.0, 2100.0, 5250.0]
# High Value Transactions: [5000]
# Total Transactions: 8000

# %% [markdown]
# ### Q17. Return a discounted amount for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def line_total(amount: float, qty: int = 1) -> float:
    """Return total transaction amount."""
    return round(amount * qty, 2)
dicount = 0.0
transaction_amounts = [1000, 2500, 5000]
print("Reference: ACC-1017")
print("Line Total:", line_total(transaction_amounts[0], 2))
print("Amounts with Charge:", list(map(lambda a: round(a * 1.05, 2), transaction_amounts)))
print("High Value Transactions:", list(filter(lambda a: a >= 2500, transaction_amounts)))
print("Total Transactions:", reduce(lambda a, b: a + b, transaction_amounts, 0))
print("Discounted Amounts:", list(map(lambda a: round(a * (1 - dicount), 2), transaction_amounts)))
# Out:
# Reference: ACC-1017
# Line Total: 2000
# Amounts with Charge: [1050.0, 2625.0, 5250.0]
# High Value Transactions: [2500, 5000]
# Total Transactions: 8500
# Discounted Amounts: [1000.0, 2500.0, 5000.0]

# %% [markdown]
# ### Q18. Use a default tax rate for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def line_total(amount: float, qty: int = 1) -> float:
    """Return total transaction amount."""
    return round(amount * qty, 2)
dicount = 0.05
tax_rate = 0.0
transaction_amounts = [1000, 2500, 5000]
print("Reference: ACC-1018")
print("Line Total:", line_total(transaction_amounts[0], 2))
print("Amounts with Charge:", list(map(lambda a: round(a * 1.05, 2), transaction_amounts)))
print("High Value Transactions:", list(filter(lambda a: a >= 2500, transaction_amounts)))
print("Total Transactions:", reduce(lambda a, b: a + b, transaction_amounts, 0))
print("Discounted Amounts:", list(map(lambda a: round(a * (1 - dicount), 2), transaction_amounts)))
print("Taxed Amounts:", list(map(lambda a: round(a * (1 + tax_rate), 2), transaction_amounts)))
# Out:
# Reference: ACC-1018
# Line Total: 2000
# Amounts with Charge: [1050.0, 2625.0, 5250.0]
# High Value Transactions: [2500, 5000]
# Total Transactions: 8500
# Discounted Amounts: [950.0, 2375.0, 4750.0]
# Taxed Amounts: [1000.0, 2500.0, 5000.0]

# %% [markdown]
# ### Q19. Accept keyword arguments for a account for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def account(**details):
    print("Reference:", details.get("reference"))
    print("Account Number:", details.get("account_number"))
    print("Account Holder:", details.get("name"))
    print("Balance:", details.get("balance"))

account(
    reference="ACC-1019",
    account_number="1234567890",
    name="Jayalakshmi",
    balance=50000
)
# Out:
# Reference: ACC-1019
# Account Number: 1234567890
# Account Holder: Jayalakshmi
# Balance: 50000

# %% [markdown]
# ### Q20. Return multiple inventory values for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def inventory_values():
    account_type = "Savings"
    available_balance = 50000
    transaction_count = 25
    return account_type, available_balance, transaction_count
reference = "ACC-1020"
account_type, balance, transactions = inventory_values()
print("Reference:", reference)
print("Account Type:", account_type)
print("Available Balance:", balance)
print("Transaction Count:", transactions)
# Out:
# Reference: ACC-1020
# Account Type: Savings
# Available Balance: 50000
# Transaction Count: 25

# %% [markdown]
# ### Q21. Write a account docstring for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def account(name, balance):
    return f"Account Holder: {name}, Balance: ₹{balance}"
reference = "ACC-1021"
print("Reference:", reference)
print(account("Jayalakshmi", 50000))
# Out:
# Reference: ACC-1021
# Account Holder: Jayalakshmi, Balance: ₹50000

# %% [markdown]
# ### Q22. Add type hints to a amount function for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def amount(value: float, charge: float = 0.0) -> float:
    """Return the total banking amount including charges."""
    return value + charge
    reference = "ACC-1022"
result = amount(5000.0, 50.0)
print("Reference:", reference)
print("Total Amount:", result)
# Out:
# Reference: ACC-1021
# Total Amount: 5050.0

# %% [markdown]
# ### Q23. Use *args to total purchases for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def total_purchases(*purchases):
    total = 0
    for purchase in purchases:
        total += purchase
    return total
reference = "ACC-1023"
purchases = [1000, 2500, 5000]
print("Reference:", reference)
print("Total Purchases:", total_purchases(*purchases))
# Out:
# Reference: ACC-1023
# Total Purchases: 8500

# %% [markdown]
# ### Q24. Use **kwargs for account attributes for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def account(**details):
    for key, value in details.items():
        print(f"{key}: {value}")
reference = "ACC-1024"
print("Reference:", reference)
account(name="Jayalakshmi", balance=50000)
print("Account Type:", account_type)
print("Available Balance:", balance)
print("Transaction Count:", transactions)
# Out:
# Reference: ACC-1024
# name: Jayalakshmi
# balance: 50000
# Account Type: Savings
# Available Balance: 50000
# Transaction Count: 25

# %% [markdown]
# ### Q25. Create a one-line amount lambda for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def amount(balance, deposit):
    return balance + deposit
amount = lambda balance, deposit: balance + deposit
reference = "ACC-1025"
result = amount(5000, 2000)
print("Reference:", reference)
print("Updated Amount:", result)
# Out:
# Reference: ACC-1025
# Updated Amount: 7000

# %% [markdown]
# ### Q26. Map amounts to tax-inclusive amounts for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def map_amounts_to_tax_inclusive_amounts(amounts):
    return list(map(lambda amount: amount * 1.1, amounts))
print("Reference: ACC-1026")
print("Amounts:", [1000, 2500, 5000])
print("Tax-Inclusive Amounts:", map_amounts_to_tax_inclusive_amounts([1000, 2500, 5000]))
# Out:
# Reference: ACC-1026
# Amounts: [1000, 2500, 5000]
# Tax-Inclusive Amounts: [1100.0, 2750.0, 5500.0]

# %% [markdown]
# ### Q27. Filter in-balance accounts for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def filter_in_balance_accounts(accounts):
    return list(filter(lambda account: account["balance"] < 0, accounts))
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": -25000},
        {"account_number": "1122334455", "balance": 20000}
    ]
print("Reference: ACC-1027")
print("In-Balance Accounts:", filter_in_balance_accounts(accounts))
# Out:
# Reference: ACC-1027
# In-Balance Accounts: [{'account_number': '0987654321', 'balance': -25000}]

# %% [markdown]
# ### Q28. Reduce a basket to its total for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def reduce_basket_to_total(basket):
    return reduce(lambda total, item: total + item["price"], basket, 0)
basket = [
        {"item": "Apple", "price": 1.0},
        {"item": "Banana", "price": 0.5},
        {"item": "Orange", "price": 0.75}
    ]
print("Reference: ACC-1028")
print("Basket:", basket)
print("Total:", reduce_basket_to_total(basket))
# Out:
# Reference: ACC-1028
# Basket: [{'item': 'Apple', 'price': 1.0}, {'item': 'Banana', 'price': 0.5}, {'item': 'Orange', 'price': 0.75}]
# Total: 2.25

# %% [markdown]
# ### Q29. Demonstrate local scope for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def demonstrate_local_scope():
    balance = 5000
    print("Balance inside function:", balance)
reference = "ACC-1029"
print("Reference:", reference)
demonstrate_local_scope()
# Out:
# Reference: ACC-1029
# Balance inside function: 5000

# %% [markdown]
# ### Q30. Write a predicate for premium accounts for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def is_premium_account(account):
    return account["balance"] >= 100000
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1030")
print("Premium Accounts:", list(filter(is_premium_account, accounts)))
# Out:
# Reference: ACC-1030
# Premium Accounts: [{'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Compose discount and tax functions for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def compose_discount_and_tax(discount, tax):
    return lambda amount: amount * (1 - discount) * (1 + tax)
    return compose_discount_and_tax
discount = 0.1
tax = 0.05
compose = compose_discount_and_tax(discount, tax)
result = compose(100)
print("Reference: ACC-1031")
print("Amount:", result)
print("Discount:", discount)
print("Tax:", tax)
# Out:
# Reference: ACC-1031
# Amount: 94.5
# Discount: 0.1
# Tax: 0.05

# %% [markdown]
# ### Q32. Sort accounts with a lambda key for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def sort_accounts(accounts):
    return sorted(accounts, key=lambda account: account["balance"])
    return sort_accounts
    accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
        ]
print("Reference: ACC-1032")
print("Sorted Accounts:", sort_accounts(accounts))
# Out:
# Reference: ACC-1032
# Sorted Accounts: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ### Q33. Group accounts using a helper function for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def group_accounts(accounts):
    return {
        "premium": list(filter(lambda account: account["balance"] >= 100000, accounts)),
        "standard": list(filter(lambda account: account["balance"] < 100000, accounts))
    }
    return group_accounts
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1033")
print("Grouped Accounts:", group_accounts(accounts))
# Out:
# Reference: ACC-1033
# Grouped Accounts: {'premium': [{'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}], 'standard': [{'account_number': '1234567890', 'balance': 50000}]}

# %% [markdown]
# ### Q34. Create a closure for category discounts for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def create_category_discount_closure(discount):
    def apply_discount(amount):
        return amount * (1 - discount)
    return apply_discount
    return create_category_discount_closure
    discount = 0.1
apply_discount = create_category_discount_closure(discount)
result = apply_discount(100)
print("Reference: ACC-1034")
print("Amount:", result)
print("Discount:", discount)
# Out:
# Reference: ACC-1034
# Amount: 90.0
# Discount: 0.1

# %% [markdown]
# ### Q35. Write a decorator that logs checkout calls for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_checkout_call(func):
    def wrapper(*args, **kwargs):
        print("Checkout call logged:", func.__name__)
        return func(*args, **kwargs)
    return wrapper
    return log_checkout_call
@log_checkout_call
def checkout():
    print("Processing checkout...")
checkout()
# Out:
# Checkout call logged: checkout
# Processing checkout...

# %% [markdown]
# ### Q36. Build a map-filter-reduce transactions pipeline for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def transactions_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return transactions_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1036")
print("Transactions:", transactions)
print("Total:", transactions_pipeline(transactions))
# Out:
# Reference: ACC-1036
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q37. Partially apply a tax function for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def partially_apply_tax(tax):
    def apply_tax(amount):
        return amount * (1 + tax)
    return apply_tax
    return partially_apply_tax
tax = 0.05
apply_tax = partially_apply_tax(tax)
result = apply_tax(100)
print("Reference: ACC-1037")
print("Amount:", result)
print("Tax:", tax)
# Out:
# Reference: ACC-1037
# Amount: 105.0
# Tax: 0.05

# %% [markdown]
# ### Q38. Use enumerate and zip in a balance report for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def balance_report(accounts):
    for index, account in enumerate(accounts):
        print(f"Account {index + 1}: {account['balance']}")
    return accounts
    return balance_report
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1038")
print("Balance Report:")
balance_report(accounts)
# Out:
# Reference: ACC-1038
# Balance Report:
# Account 1: 50000
# Account 2: 150000
# Account 3: 200000
# [{'account_number': '1234567890', 'balance': 50000},
#  {'account_number': '0987654321', 'balance': 150000},
#  {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ### Q39. Write a generator for low-balance accounts for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def low_balance_accounts(accounts):
    for account in accounts:
        if account["balance"] < 0:
            yield account
    return low_balance_accounts
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": -25000},
        {"account_number": "1122334455", "balance": 20000}
    ]
print("Reference: ACC-1039")
print("Low-Balance Accounts:")
for account in low_balance_accounts(accounts):
    print(account)
# Out:
# Reference: ACC-1039
# Low-Balance Accounts:
# {'account_number': '0987654321', 'balance': -25000}

# %% [markdown]
# ### Q40. Implement recursive category total for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def recursive_category_total(category):
    if not category:
        return 0
        total = category["total"]
        total += recursive_category_total(category["subcategories"])
        return total
        return recursive_category_total
category = {
        "name": "Electronics",
        "total": 1000,
        "subcategories": {
            "name": "Laptops",
            "total": 500,
            "subcategories": {}
        }
    }
print("Reference: ACC-1040")
print("Category Total:", recursive_category_total(category))
# Out:
# Reference: ACC-1040
# Category Total: None

# %% [markdown]
# ### Q41. Validate arguments with a wrapper for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def validate_arguments(func):
    def wrapper(*args, **kwargs):
        if not args:
            raise ValueError("No arguments provided")
        return func(*args, **kwargs)
    return wrapper
    return validate_arguments
@validate_arguments
def add_numbers(a, b):
    return a + b
result = add_numbers(5, 10)
print("Reference: ACC-1041")
print("Result:", result)
# Out:
# Reference: ACC-1041
# Result: 15

# %% [markdown]
# ### Q42. Return a function selected by interest offer type for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def return_interest_offer_function(offer_type):
    if offer_type == "fixed":
        def fixed_interest_offer(amount):
            return amount * 1.05
        return fixed_interest_offer
    elif offer_type == "variable":
        def variable_interest_offer(amount):
            return amount * 1.1
        return variable_interest_offer
    else:
        raise ValueError("Invalid offer type")
        return return_interest_offer_function
fixed_offer = return_interest_offer_function("fixed")
result = fixed_offer(100)
print("Reference: ACC-1042")
print("Result:", result)
# Out:
# Reference: ACC-1042
# Result: 105.0

# %% [markdown]
# ### Q43. Keep a pricing function pure for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def keep_pricing_function_pure(price):
    def apply_discount(discount):
        return price * (1 - discount)
    return apply_discount
    return keep_pricing_function_pure
price = 100
apply_discount = keep_pricing_function_pure(price)
result = apply_discount(0.1)
print("Reference: ACC-1043")
print("Price:", price)
print("Discount:", 0.1)
# Out:
# Reference: ACC-1043
# Price: 100
# Discount: 0.1

# %% [markdown]
# ### Q44. Calculate basket metrics in one pass for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def calculate_basket_metrics(basket):
    total_price = reduce(lambda total, item: total + item["price"], basket, 0)
    total_quantity = reduce(lambda total, item: total + item["quantity"], basket, 0)
    return total_price, total_quantity
    return calculate_basket_metrics
basket = [
        {"item": "Apple", "price": 1.0, "quantity": 5},
        {"item": "Banana", "price": 0.5, "quantity": 3},
        {"item": "Orange", "price": 0.75, "quantity": 2}
    ]
print("Reference: ACC-1044")
print("Basket:", basket)
print("Total Price:", calculate_basket_metrics(basket)[0])
# Out:
# Reference: ACC-1044
# Basket: [{'item': 'Apple', 'price': 1.0, 'quantity': 5}, {'item': 'Banana', 'price': 0.5, 'quantity': 3}, {'item': 'Orange', 'price': 0.75, 'quantity': 2}]
# Total Price: 2.25

# %% [markdown]
# ### Q45. Unit-test a reusable banking function for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
import unittest
def calculate_balance(balance: float, deposit: float) -> float:
    """Return the updated account balance."""
    return balance + deposit
class TestBanking(unittest.TestCase):
    def test_calculate_balance(self):
        result = calculate_balance(5000, 2000)
        self.assertEqual(result, 7000)
if __name__ == "__main__":
    print("Reference: ACC-1045")
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.002s
#
# OK
# Reference: ACC-1045

# %% [markdown]
# ### Q46. Compose discount and tax functions for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def compose_discount_and_tax(discount, tax):
    return lambda amount: amount * (1 - discount) * (1 + tax)
    return compose_discount_and_tax
discount = 0.1
tax = 0.05
compose = compose_discount_and_tax(discount, tax)
result = compose(100)
print("Reference: ACC-1046")
print("Amount:", result)
print("Discount:", discount)
print("Tax:", tax)
# Out:
# Reference: ACC-1046
# Amount: 94.5
# Discount: 0.1
# Tax: 0.05

# %% [markdown]
# ### Q47. Sort accounts with a lambda key for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def sort_accounts(accounts):
    return sorted(accounts, key=lambda account: account["balance"])
    return sort_accounts
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
        ]
print("Reference: ACC-1047")
print("Sorted Accounts:", sort_accounts(accounts))
# Out:
# Reference: ACC-1047
# Sorted Accounts: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ### Q48. Group accounts using a helper function for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def group_accounts(accounts):
    return {
        "premium": list(filter(lambda account: account["balance"] >= 100000, accounts)),
        "standard": list(filter(lambda account: account["balance"] < 100000, accounts))
    }
    return group_accounts
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 250000},
        {"account_number": "1122334455", "balance": 150000}
    ]
print("Reference: ACC-1048")
print("Grouped Accounts:", group_accounts(accounts))
# Out:
# Reference: ACC-1048
# Grouped Accounts: {'premium': [{'account_number': '0987654321', 'balance': 250000}, {'account_number': '1122334455', 'balance': 150000}], 'standard': [{'account_number': '1234567890', 'balance': 50000}]}

# %% [markdown]
# ### Q49. Create a closure for category discounts for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def create_category_discount_closure(discount):
    def apply_discount(amount):
        return amount * (1 - discount)
    return apply_discount
    return create_category_discount_closure
discount = 0.1
apply_discount = create_category_discount_closure(discount)
result = apply_discount(100)
print("Reference: ACC-1049")
print("Amount:", result)
print("Discount:", discount)
# Out:
# Reference: ACC-1049
# Amount: 90.0
# Discount: 0.1

# %% [markdown]
# ### Q50. Write a decorator that logs checkout calls for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_checkout_call(func):
    def wrapper(*args, **kwargs):
        print("Checkout call logged:", func.__name__)
        return func(*args, **kwargs)
    return wrapper
    return log_checkout_call
@log_checkout_call
def checkout():
    print("Processing checkout...")
checkout()
# Out:
# Checkout call logged: checkout
# Processing checkout...

# %% [markdown]
# ### Q51. Build a map-filter-reduce transactions pipeline for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def transactions_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return transactions_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1051")
print("Transactions:", transactions)
print("Total:", transactions_pipeline(transactions))
# Out:
# Reference: ACC-1051
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q52. Partially apply a tax function for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def partially_apply_tax(tax):
    def apply_tax(amount):
        return amount * (1 + tax)
    return apply_tax
    return partially_apply_tax
tax = 0.05
apply_tax = partially_apply_tax(tax)
result = apply_tax(100)
print("Reference: ACC-1052")
print("Amount:", result)
print("Tax:", tax)
# Out:
# Reference: ACC-1052
# Amount: 105.0
# Tax: 0.05

# %% [markdown]
# ### Q53. Use enumerate and zip in a balance report for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def balance_report(accounts):
    for index, account in enumerate(accounts):
        print(f"Account {index + 1}: {account['balance']}")
    return accounts
    return balance_report
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1053")
print("Balance Report:")
balance_report(accounts)
# Out:
# Reference: ACC-1053
# Balance Report:
# Account 1: 50000
# Account 2: 150000
# Account 3: 200000
# [{'account_number': '1234567890', 'balance': 50000},
#  {'account_number': '0987654321', 'balance': 150000},
#  {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ### Q54. Write a generator for low-balance accounts for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def low_balance_accounts(accounts):
    for account in accounts:
        if account["balance"] < 0:
            yield account
    return low_balance_accounts
    return low_balance_accounts
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": -25000},
        {"account_number": "1122334455", "balance": 20000}
    ]
print("Reference: ACC-1054")
print("Low-Balance Accounts:")
for account in low_balance_accounts(accounts):
    print(account)
# Out:
# Reference: ACC-1054
# Low-Balance Accounts:
# {'account_number': '0987654321', 'balance': -25000}

# %% [markdown]
# ### Q55. Implement recursive category total for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def recursive_category_total(category):
    if not category:
        return 0
        total = category["total"]
        total += recursive_category_total(category["subcategories"])
        return total
        return recursive_category_total
category = {
        "name": "Electronics",
        "total": 1000,
        "subcategories": {
            "name": "Laptops",
            "total": 500,
            "subcategories": {}
        }
    }
print("Reference: ACC-1055")
print("Category Total:", recursive_category_total(category))
# Out:
# Reference: ACC-1055
# Category Total: None

# %% [markdown]
# ### Q56. Validate arguments with a wrapper for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def validate_arguments(func):
    def wrapper(*args, **kwargs):
        if not args:
            raise ValueError("No arguments provided")
        return func(*args, **kwargs)
    return wrapper
    return validate_arguments
@validate_arguments
def add_numbers(a, b):
    return a + b
result = add_numbers(5, 10)
print("Reference: ACC-1056")
print("Result:", result)
# Out:
# Reference: ACC-1056
# Result: 15

# %% [markdown]
# ### Q57. Return a function selected by interest offer type for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def return_interest_offer_function(offer_type):
    if offer_type == "fixed":
        def fixed_interest_offer(amount):
            return amount * 1.05
        return fixed_interest_offer
    elif offer_type == "variable":
        def variable_interest_offer(amount):
            return amount * 1.1
        return variable_interest_offer
    else:
        raise ValueError("Invalid offer type")
        return return_interest_offer_function
fixed_offer = return_interest_offer_function("fixed")
result = fixed_offer(100)
print("Reference: ACC-1057")
print("Result:", result)
# Out:
# Reference: ACC-1057
# Result: 105.0

# %% [markdown]
# ### Q58. Keep a pricing function pure for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def keep_pricing_function_pure(price):
    def apply_discount(discount):
        return price * (1 - discount)
    return apply_discount
    return keep_pricing_function_pure
price = 100
apply_discount = keep_pricing_function_pure(price)
result = apply_discount(0.1)
print("Reference: ACC-1058")
print("Price:", price)
print("Discount:", 0.1)
# Out:
# Reference: ACC-1058
# Price: 100
# Discount: 0.1

# %% [markdown]
# ### Q59. Calculate basket metrics in one pass for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def calculate_basket_metrics(basket):
    total_price = reduce(lambda total, item: total + item["price"], basket, 0)
    total_quantity = reduce(lambda total, item: total + item["quantity"], basket, 0)
    return total_price
    return calculate_basket_metrics
    basket = [
        {"item": "Apple", "price": 1.0, "quantity": 5},
        {"item": "Banana", "price": 0.5, "quantity": 3},
        {"item": "Orange", "price": 0.75, "quantity": 2}
    ]
print("Reference: ACC-1059")
print("Basket:", basket)
print("Total Price:", calculate_basket_metrics(basket))
# Out:
# Reference: ACC-1059
# Basket: [{'item': 'Apple', 'price': 1.0, 'quantity': 5}, {'item': 'Banana', 'price': 0.5, 'quantity': 3}, {'item': 'Orange', 'price': 0.75, 'quantity': 2}]
# Total Price: 2.25

# %% [markdown]
# ### Q60. Unit-test a reusable banking function for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def calculate_balance(balance: float, deposit: float) -> float:
    """Return the updated account balance."""
    return balance + deposit
    return calculate_balance
    class TestBanking(unittest.TestCase):
        def test_calculate_balance(self):
            result = calculate_balance(5000, 2000)
            self.assertEqual(result, 7000)
            if __name__ == "__main__":
              print("Reference: ACC-1060")
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.015s
#
# OK

# %% [markdown]
# ### Q61. Compose discount and tax functions for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def compose_discount_and_tax(discount, tax):
    return lambda amount: amount * (1 - discount) * (1 + tax)
    return compose_discount_and_tax
discount = 0.1
tax = 0.05
compose = compose_discount_and_tax(discount, tax)
result = compose(100)
print("Reference: ACC-1061")
print("Amount:", result)
print("Discount:", discount)
print("Tax:", tax)
# Out:
# Reference: ACC-1061
# Amount: 94.5
# Discount: 0.1
# Tax: 0.05

# %% [markdown]
# ### Q62. Sort accounts with a lambda key for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def sort_accounts(accounts):
    return sorted(accounts, key=lambda account: account["balance"])
    return sort_accounts
    accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
        ]
print("Reference: ACC-1062")
print("Sorted Accounts:", sort_accounts(accounts))
# Out:
# Reference: ACC-1062
# Sorted Accounts: [{'account_number': '0987654321', 'balance': -25000}, {'account_number': '1122334455', 'balance': 20000}, {'account_number': '1234567890', 'balance': 50000}]

# %% [markdown]
# ### Q63. Group accounts using a helper function for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def group_accounts(accounts):
    return {
        "premium": list(filter(lambda account: account["balance"] >= 100000, accounts)),
        "standard": list(filter(lambda account: account["balance"] < 100000, accounts))
    }
    return group_accounts
accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 250000},
        {"account_number": "1122334455", "balance": 150000}
    ]
print("Reference: ACC-1063")
print("Grouped Accounts:", group_accounts(accounts))
# Out:
# Reference: ACC-1063
# Grouped Accounts: {'premium': [{'account_number': '0987654321', 'balance': 250000}, {'account_number': '1122334455', 'balance': 150000}], 'standard': [{'account_number': '1234567890', 'balance': 50000}]}

# %% [markdown]
# ### Q64. Create a closure for category discounts for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def create_category_discount_closure(discount):
    def apply_discount(amount):
        return amount * (1 - discount)
    return apply_discount
    return create_category_discount_closure
discount = 0.1
apply_discount = create_category_discount_closure(discount)
result = apply_discount(100)
print("Reference: ACC-1064")
print("Amount:", result)
print("Discount:", discount)
# Out:
# Reference: ACC-1064
# Amount: 90.0
# Discount: 0.1

# %% [markdown]
# ### Q65. Write a decorator that logs checkout calls for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_checkout_call(func):
    def wrapper(*args, **kwargs):
        print("Checkout call logged:", func.__name__)
        return func(*args, **kwargs)
    return wrapper
    return log_checkout_call
@log_checkout_call
def checkout():
    print("Processing checkout...")
checkout()
# Out:
# Checkout call logged: checkout
# Processing checkout...

# %% [markdown]
# ### Q66. Build a map-filter-reduce transactions pipeline for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def transactions_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return transactions_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1066")
print("Transactions:", transactions)
print("Total:", transactions_pipeline(transactions))
# Out:
# Reference: ACC-1066
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q67. Partially apply a tax function for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def partially_apply_tax(tax):
    def apply_tax(amount):
        return amount * (1 + tax)
    return apply_tax
    return partially_apply_tax
    tax = 0.05
apply_tax = partially_apply_tax(tax)
result = apply_tax(100)
print("Reference: ACC-1067")
print("Amount:", result)
print("Tax:", tax)
# Out:
# Reference: ACC-1067
# Amount: 105.0
# Tax: 0.05

# %% [markdown]
# ### Q68. Use enumerate and zip in a balance report for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def balance_report(accounts):
    for index, account in enumerate(accounts):
        print(f"Account {index + 1}: {account['balance']}")
    return accounts
    return balance_report
    accounts = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1068")
print("Balance Report:")
balance_report(accounts)
# Out:
# Reference: ACC-1068
# Balance Report:
# Account 1: 50000
# Account 2: 250000
# Account 3: 150000
# [{'account_number': '1234567890', 'balance': 50000},
#  {'account_number': '0987654321', 'balance': 250000},
#  {'account_number': '1122334455', 'balance': 150000}]

# %% [markdown]
# ### Q69. Write a generator for low-balance accounts for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def low_balance_accounts(accounts):
    for account in accounts:
        if account["balance"] < 0:
            yield account
    return low_balance_accounts
    return low_balance_accounts
accounts = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": -25000},
    {"account_number": "1122334455", "balance": 20000}
]
print("Reference: ACC-1069")
print("Low-Balance Accounts:")
for account in low_balance_accounts(accounts):
    print(account)
# Out:
# Reference: ACC-1069
# Low-Balance Accounts:
# {'account_number': '0987654321', 'balance': -25000}

# %% [markdown]
# ### Q70. Implement recursive category total for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def recursive_category_total(category):
    if not category:
        return 0
        total = category["total"]
        total += recursive_category_total(category["subcategories"])
        return total
        return recursive_category_total
category = {
        "name": "Electronics",
        "total": 1000,
        "subcategories": {
            "name": "Laptops",
            "total": 500,
            "subcategories": {}
        }
    }
print("Reference: ACC-1070")
print("Category Total:", recursive_category_total(category))
# Out:
# Reference: ACC-1070
# Category Total: None

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design a configurable transformation pipeline for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def configurable_transformation_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return configurable_transformation_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1071")
print("Transactions:", transactions)
print("Total:", configurable_transformation_pipeline(transactions))
# Out:
# Reference: ACC-1071
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q72. Implement memoized demand calculation for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def memoized_demand_calculation(price):
    demand_cache = {}
    def calculate_demand(quantity):
        if quantity in demand_cache:
            return demand_cache[quantity]
        demand = price * quantity
        demand_cache[quantity] = demand
        return demand
    return calculate_demand
    return memoized_demand_calculation
price = 10
calculate_demand = memoized_demand_calculation(price)
result = calculate_demand(5)
print("Reference: ACC-1072")
print("Price:", price)
print("Quantity:", 5)
# Out:
# Reference: ACC-1072
# Price: 10
# Quantity: 5

# %% [markdown]
# ### Q73. Build a decorator with arguments for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_checkout_call(func):
    def wrapper(*args, **kwargs):
        print("Checkout call logged:", func.__name__)
        return func(*args, **kwargs)
    return wrapper
    return log_checkout_call
@log_checkout_call
def checkout():
    print("Processing checkout...")
checkout()
# Out:
# Checkout call logged: checkout
# Processing checkout...

# %% [markdown]
# ### Q74. Create a function registry for interest offers for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def create_interest_offer(interest_rate):
    def apply_interest(amount):
        return amount * (1 + interest_rate)
    return apply_interest
    return create_interest_offer
interest_rate = 0.05
apply_interest = create_interest_offer(interest_rate)
result = apply_interest(100)
print("Reference: ACC-1074")
print("Amount:", result)
# Out:
# Reference: ACC-1074
# Amount: 105.0

# %% [markdown]
# ### Q75. Implement a currying example for amounts for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def currying_example(amount):
    def apply_interest(interest_rate):
        return amount * (1 + interest_rate)
    return apply_interest
    return currying_example
amount = 100
apply_interest = currying_example(amount)
result = apply_interest(0.05)
print("Reference: ACC-1075")
print("Amount:", result)
# Out:
# Reference: ACC-1075
# Amount: 105.0

# %% [markdown]
# ### Q76. Compare lazy generators with eager map results for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def lazy_generators_with_eager_map_results(accounts):
    return map(lambda account: account["balance"], accounts)
    return lazy_generators_with_eager_map_results
account = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
]
print("Reference: ACC-1076")
print("Lazy Generators with Eager Map Results:")
for balance in lazy_generators_with_eager_map_results(accounts):
    print(balance)
# Out:
# Reference: ACC-1076
# Lazy Generators with Eager Map Results:
# 50000
# -25000
# 20000

# %% [markdown]
# ### Q77. Write a robust reduce for grouped totals for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def robust_reduce_for_grouped_totals(accounts):
    return reduce(lambda total, account: total + account["balance"], accounts, 0)
    return robust_reduce_for_grouped_totals
accounts = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
]
print("Reference: ACC-1077")
print("Accounts:", accounts)
print("Total Balance:", robust_reduce_for_grouped_totals(accounts))
# Out:
# Reference: ACC-1077
# Accounts: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]
# Total Balance: 400000

# %% [markdown]
# ### Q78. Implement retry as a higher-transfer function for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def retry(func):
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            print("Retry attempt:", e)
            return func(*args, **kwargs)
    return wrapper
    return retry
@retry
def divide(a, b):
    return a / b
result = divide(10, 2)
print("Reference: ACC-1078")
print("Result:", result)
# Out:
# Reference: ACC-1078
# Result: 5.0

# %% [markdown]
# ### Q79. Create a functional checkout with immutable updates for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def functional_checkout(accounts):
    return map(lambda account: account["balance"], accounts)
    return functional_checkout
account = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
]
print("Reference: ACC-1079")
print("Accounts:", accounts)
print("Functional Checkout:")
for balance in functional_checkout(accounts):
    print(balance)
# Out:
# Reference: ACC-1079
# Accounts: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]
# Functional Checkout:
# 50000
# 150000
# 200000

# %% [markdown]
# ### Q80. Design an end-to-end transactions analytics pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def end_to_end_transactions_analytics_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return end_to_end_transactions_analytics_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1080")
print("Transactions:", transactions)
print("Total:", end_to_end_transactions_analytics_pipeline(transactions))
# Out:
# Reference: ACC-1080
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q81. Design a configurable transformation pipeline for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def configurable_transformation_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return configurable_transformation_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1081")
print("Transactions:", transactions)
print("Total:", configurable_transformation_pipeline(transactions))
# Out:
# Reference: ACC-1081
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q82. Implement memoized demand calculation for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def memoized_demand_calculation(price):
    demand_cache = {}
    def calculate_demand(quantity):
        if quantity in demand_cache:
            return demand_cache[quantity]
        demand = price * quantity
        demand_cache[quantity] = demand
        return demand
    return calculate_demand
    return memoized_demand_calculation
price = 10
calculate_demand = memoized_demand_calculation(price)
result = calculate_demand(5)
print("Reference: ACC-1082")
print("Price:", price)
# Out:
# Reference: ACC-1082
# Price: 10

# %% [markdown]
# ### Q83. Build a decorator with arguments for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_checkout_call(func):
    def wrapper(*args, **kwargs):
        print("Checkout call logged:", func.__name__)
        return func(*args, **kwargs)
    return wrapper
    return log_checkout_call
@log_checkout_call
def checkout():
    print("Processing checkout...")
checkout()
# Out:
# Checkout call logged: checkout
# Processing checkout...

# %% [markdown]
# ### Q84. Create a function registry for interest offers for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def create_interest_offer(interest_rate):
    def apply_interest(amount):
        return amount * (1 + interest_rate)
    return apply_interest
    return create_interest_offer
interest_rate = 0.05
apply_interest = create_interest_offer(interest_rate)
result = apply_interest(100)
print("Reference: ACC-1084")
print("Amount:", result)
# Out:
# Reference: ACC-1084
# Amount: 105.0

# %% [markdown]
# ### Q85. Implement a currying example for amounts for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def currying_example(amount):
    def apply_interest(interest_rate):
        return amount * (1 + interest_rate)
    return apply_interest
    return currying_example
amount = 100
apply_interest = currying_example(amount)
result = apply_interest(0.05)
print("Reference: ACC-1085")
print("Amount:", result)
# Out:
# Reference: ACC-1085
# Amount: 105.0

# %% [markdown]
# ### Q86. Compare lazy generators with eager map results for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def lazy_generators_with_eager_map_results(accounts):
    return map(lambda account: account["balance"], accounts)
    return lazy_generators_with_eager_map_results
account = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
]
print("Reference: ACC-1086")
print("Lazy Generators with Eager Map Results:")
for balance in lazy_generators_with_eager_map_results(accounts):
    print(balance)
# Out:
# Reference: ACC-1086
# Lazy Generators with Eager Map Results:
# 50000
# 150000
# 200000

# %% [markdown]
# ### Q87. Write a robust reduce for grouped totals for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def robust_reduce_for_grouped_totals(accounts):
    return reduce(lambda total, account: total + account["balance"], accounts, 0)
    return robust_reduce_for_grouped_totals
account = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
]
print("Reference: ACC-1087")
print("Accounts:", accounts)
print("Total Balance:", robust_reduce_for_grouped_totals(accounts))
# Out:
# Reference: ACC-1087
# Accounts: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]
# Total Balance: 400000

# %% [markdown]
# ### Q88. Implement retry as a higher-transfer function for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def retry(func):
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            print("Retry attempt:", e)
            return func(*args, **kwargs)
    return wrapper
    return retry
@retry
def divide(a, b):
    return a / b
result = divide(10, 2)
print("Reference: ACC-1088")
print("Result:", result)
# Out:
# Reference: ACC-1088
# Result: 5.0

# %% [markdown]
# ### Q89. Create a functional checkout with immutable updates for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def functional_checkout(accounts):
    return map(lambda account: account["balance"], accounts)
    return functional_checkout
account = [
        {"account_number": "1234567890", "balance": 50000},
        {"account_number": "0987654321", "balance": 150000},
        {"account_number": "1122334455", "balance": 200000}
    ]
print("Reference: ACC-1089")
print("Accounts:", accounts)
print("Functional Checkout:")
for balance in functional_checkout(accounts):
    print(balance)
# Out:
# Reference: ACC-1089
# Accounts: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]
# Functional Checkout:
# 50000
# 150000
# 200000

# %% [markdown]
# ### Q90. Design an end-to-end transactions analytics pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def end_to_end_transactions_analytics_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return end_to_end_transactions_analytics_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1090")
print("Transactions:", transactions)
print("Total:", end_to_end_transactions_analytics_pipeline(transactions))
# Out:
# Reference: ACC-1090
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q91. Design a configurable transformation pipeline for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def configurable_transformation_pipeline(transactions):
    return reduce(lambda total, transaction: total + transaction["amount"], transactions, 0)
    return configurable_transformation_pipeline
transactions = [
        {"transaction_id": 1, "amount": 100},
        {"transaction_id": 2, "amount": 250},
        {"transaction_id": 3, "amount": 500}
    ]
print("Reference: ACC-1091")
print("Transactions:", transactions)
print("Total:", configurable_transformation_pipeline(transactions))
# Out:
# Reference: ACC-1091
# Transactions: [{'transaction_id': 1, 'amount': 100}, {'transaction_id': 2, 'amount': 250}, {'transaction_id': 3, 'amount': 500}]
# Total: 850

# %% [markdown]
# ### Q92. Implement memoized demand calculation for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def memoized_demand_calculation(price):
    demand_cache = {}
    def calculate_demand(quantity):
        if quantity in demand_cache:
            return demand_cache[quantity]
        demand = price * quantity
        demand_cache[quantity] = demand
        return demand
        return calculate_demand
    return memoized_demand_calculation
price = 10
calculate_demand = memoized_demand_calculation(price)
result = calculate_demand(5)
print("Reference: ACC-1092")
print("Price:", price)
# Out:
# Reference: ACC-1092
# Price: 10

# %% [markdown]
# ### Q93. Build a decorator with arguments for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def log_checkout_call(func):
    def wrapper(*args, **kwargs):
        print("Checkout call logged:", func.__name__)
        return func(*args, **kwargs)
    return wrapper
    return log_checkout_call
@log_checkout_call
def checkout():
    print("Processing checkout...")
checkout()
# Out:
# Checkout call logged: checkout
# Processing checkout...

# %% [markdown]
# ### Q94. Create a function registry for interest offers for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def create_interest_offer(interest_rate):
    def apply_interest(amount):
        return amount * (1 + interest_rate)
    return apply_interest
    return create_interest_offer
interest_rate = 0.05
apply_interest = create_interest_offer(interest_rate)
result = apply_interest(100)
print("Reference: ACC-1094")
print("Amount:", result)
# Out:
# Reference: ACC-1094
# Amount: 105.0

# %% [markdown]
# ### Q95. Implement a currying example for amounts for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def currying_example(amount):
    def apply_interest(interest_rate):
        return amount * (1 + interest_rate)
    return apply_interest
    return currying_example
amount = 100
apply_interest = currying_example(amount)
result = apply_interest(0.05)
print("Reference: ACC-1095")
print("Amount:", result)
# Out:
# Reference: ACC-1095
# Amount: 105.0

# %% [markdown]
# ### Q96. Compare lazy generators with eager map results for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def lazy_generators_with_eager_map_results(accounts):
    return map(lambda account: account["balance"], accounts)
    return lazy_generators_with_eager_map_results
account = [
    {"account_number": "1234567890", "balance": 50000},
    {"account_number": "0987654321", "balance": 150000},
    {"account_number": "1122334455", "balance": 200000}
]
print("Reference: ACC-1096")
print("Lazy Generators with Eager Map Results:")
for balance in lazy_generators_with_eager_map_results(accounts):
    print(balance)
# Out:
# Reference: ACC-1096
# Lazy Generators with Eager Map Results:
# 50000
# 150000
# 200000

# %% [markdown]
# ### Q97. Write a robust reduce for grouped totals for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from functools import reduce
transactions = [
    ("Savings", 5000),
    ("Current", 8000),
    ("Savings", 3000),
    ("Current", 2000),
    ("Fixed Deposit", 10000)
]
def grouped_totals(data):
    return reduce(
        lambda totals, item: {
            **totals,
            item[0]: totals.get(item[0], 0) + item[1]
        },
        data,
        {}
    )
result = grouped_totals(transactions)
print("Reference: ACC-1097")
print("Grouped Totals:", result)
# Out:
# Reference: ACC-1097
# Grouped Totals: {'Savings': 8000, 'Current': 10000, 'Fixed Deposit': 10000}

# %% [markdown]
# ### Q98. Implement retry as a higher-transfer function for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def retry(func):
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            print("Retry attempt:", e)
            return func(*args, **kwargs)
    return wrapper
    return retry
@retry
def divide(a, b):
    return a / b
result = divide(10, 2)
print("Reference: ACC-1098")
print("Result:", result)
# Out:
# Reference: ACC-1098
# Result: 5.0

# %% [markdown]
# ### Q99. Create a functional checkout with immutable updates for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def functional_checkout(account):
    return {
        **account,
        "balance": account["balance"] + 100
    }
    return functional_checkout
    account = {
        "account_number": "1234567890",
        "balance": 50000
    }
print("Reference: ACC-1099")
print("Account:", account)
# Out:
# Reference: ACC-1099
# Account: [{'account_number': '1234567890', 'balance': 50000}, {'account_number': '0987654321', 'balance': 150000}, {'account_number': '1122334455', 'balance': 200000}]

# %% [markdown]
# ### Q100. Design an end-to-end transactions analytics pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. First express the input and return value of one pure function.
# 2. Use `filter` for selection, `map` for transformation, and `reduce` only when a clearer built-in is not available.
# 3. Test the pipeline with an empty collection and avoid mutating account records in place.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
